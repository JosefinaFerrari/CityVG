# %% [markdown]
# # Recommender

# %% [markdown]
# The preferences of the user are contained in a structure like this one:
# ```python
# user_preferences = {
#   "available_dates": ["2024-11-15T09:30:00", "2024-11-16T21:30:00"],
#   "budget": "balanced",
#   "preferred_categories": ["museum", "park", "castle", "monument"]
#   }
# ```
# Similarly, the location's features:
# ```python
# location = {
#   "not_available_dates": [2024-11-16], # The available dates will be much more than the not available ones
#   "budget": "cheap",
#   "categories": ["museum", "history", "renaissance"]
# }
# ```

# %%
FOURSQUARE_API_KEY = "fsq3yHzP7Fs1u0ArTTFHsZchrCOl1ww2W/WnYgcez3Xi1Jc="

GOOGLE_PLACES_API_KEY = "AIzaSyBZ0uWQRkbEmGSj-u9a6Ar8-Avn8QpkCXU"

TIQETS_API_KEY = "wxMe9PEf0xzZMtfsFy9OwQM4lMC3H2mC"

# %%
import requests
from fuzzywuzzy import fuzz
from geopy.distance import geodesic
from django.http import JsonResponse
# Out:
# c:\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## Get places details

# %%
def get_places_in_city_foursquare(city):
    api_url = "https://api.foursquare.com/v3/places/search"

    headers = {
        "Accept": "application/json",
        "Authorization": FOURSQUARE_API_KEY
    }

    params = {
        "near": city,
        "query": "all places to visit or to see",
        "limit": 50
    }

    try:
        # Make the GET request to the Tiqets API
        response = requests.get(api_url, headers=headers, params=params)

        # Check if the response status is OK
        if response.status_code == 200:
            return response.json()  # Return the JSON response with the data
        else:
            return {'error': 'Failed to fetch data from Tiqets API', 'status_code': response.status_code}
    except Exception as e:
        return {'error': str(e)}

# %%
get_places_in_city_foursquare("Milano")
# Out:
# {'results': [{'fsq_id': '5efcaee35331640008d57451',
#    'categories': [{'id': 13258,
#      'name': 'Trattoria',
#      'short_name': 'Trattoria/Osteria',
#      'plural_name': 'Trattorias',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}},
#     {'id': 13039,
#      'name': 'Deli',
#      'short_name': 'Deli',
#      'plural_name': 'Delis',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 415,
#    'geocodes': {'drop_off': {'latitude': 45.461333, 'longitude': 9.186458},
#     'main': {'latitude': 45.461355, 'longitude': 9.186311},
#     'roof': {'latitude': 45.461355, 'longitude': 9.186311}},
#    'link': '/v3/places/5efcaee35331640008d57451',
#    'location': {'address': 'Via Lupetta 12',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Lupetta 12, 20123 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Lombardia'},
#    'name': "All' Antico Vinaio - Milano",
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4da44c9df889cbff059b0f40',
#    'categories': [{'id': 17043,
#      'name': 'Clothing Store',
#      'short_name': 'Apparel',
#      'plural_name': 'Clothing Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 577,
#    'geocodes': {'drop_off': {'latitude': 45.461815, 'longitude': 9.183044},
#     'main': {'latitude': 45.461961, 'longitude': 9.182956},
#     'roof': {'latitude': 45.461961, 'longitude': 9.182956}},
#    'link': '/v3/places/4da44c9df889cbff059b0f40',
#    'location': {'address': 'Via Santa Marta 14',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Santa Marta 14, 20123 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Lombardia'},
#    'name': 'Wait And See',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '54f9516d498ec6be00d55b9a',
#    'categories': [{'id': 19012,
#      'name': 'Cabin',
#      'short_name': 'Cabin',
#      'plural_name': 'Cabins',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'}},
#     {'id': 19014,
#      'name': 'Hotel',
#      'short_name': 'Hotel',
#      'plural_name': 'Hotels',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 2181,
#    'geocodes': {'drop_off': {'latitude': 45.481517, 'longitude': 9.202478},
#     'main': {'latitude': 45.481634, 'longitude': 9.202535},
#     'roof': {'latitude': 45.481634, 'longitude': 9.202535}},
#    'link': '/v3/places/54f9516d498ec6be00d55b9a',
#    'location': {'address': 'Via Alfredo Cappellini 23',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Alfredo Cappellini 23, 20124 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20124',
#     'region': 'Lombardia'},
#    'name': 'Made to Measure Business',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '602270597ea81e0498b2b49b',
#    'categories': [{'id': 17043,
#      'name': 'Clothing Store',
#      'short_name': 'Apparel',
#      'plural_name': 'Clothing Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 64,
#    'geocodes': {'main': {'latitude': 45.464804, 'longitude': 9.18906},
#     'roof': {'latitude': 45.464804, 'longitude': 9.18906}},
#    'link': '/v3/places/602270597ea81e0498b2b49b',
#    'location': {'address': 'Piazza del Duomo 1',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Piazza del Duomo 1, 20121 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Lombardia'},
#    'name': 'Celine Milan Rinascente Ready To Wear',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '52851a38498e436cee866440',
#    'categories': [{'id': 17045,
#      'name': 'Jewelry Store',
#      'short_name': 'Jewelry',
#      'plural_name': 'Jewelry Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 324,
#    'geocodes': {'main': {'latitude': 45.461648, 'longitude': 9.190441},
#     'roof': {'latitude': 45.461648, 'longitude': 9.190441}},
#    'link': '/v3/places/52851a38498e436cee866440',
#    'location': {'address': 'Via Paolo da Cannobio 9',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Paolo da Cannobio 9, 20122 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Lombardia'},
#    'name': 'To Be Packing SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': 'cf111e17c18a4f5cbd993e42',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 384,
#    'geocodes': {'drop_off': {'latitude': 45.463698, 'longitude': 9.194371},
#     'main': {'latitude': 45.463676, 'longitude': 9.194373}},
#    'link': '/v3/places/cf111e17c18a4f5cbd993e42',
#    'location': {'address': 'Via Meravigli 13',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Meravigli 13, 20123 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Lombardia'},
#    'name': 'K2real Key To Real SRL K2r',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '74c5211d9f2f4e0c3f1366dd',
#    'categories': [{'id': 11038,
#      'name': 'Event Service',
#      'short_name': 'Event Services',
#      'plural_name': 'Event Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/event/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 712,
#    'geocodes': {'drop_off': {'latitude': 45.470192, 'longitude': 9.185793},
#     'main': {'latitude': 45.470136, 'longitude': 9.185808},
#     'roof': {'latitude': 45.470136, 'longitude': 9.185808}},
#    'link': '/v3/places/74c5211d9f2f4e0c3f1366dd',
#    'location': {'address': 'Via del Carmine 11',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via del Carmine 11, 20121 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Lombardia'},
#    'name': 'B2G Business To Green SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': 'fda4e10da5a0d2abce9176ae',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 806,
#    'geocodes': {'main': {'latitude': 45.468529, 'longitude': 9.181135},
#     'roof': {'latitude': 45.468529, 'longitude': 9.181135}},
#    'link': '/v3/places/fda4e10da5a0d2abce9176ae',
#    'location': {'address': 'Via Luca Beltrami 1',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Luca Beltrami 1, 20121 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Lombardia'},
#    'name': 'Gate - A Way To Italy',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '3dd96de10b2c4f29a3efb683',
#    'categories': [{'id': 11046,
#      'name': 'Banking and Finance',
#      'short_name': 'Banking and Finance',
#      'plural_name': 'Banking and Finances',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 935,
#    'geocodes': {'drop_off': {'latitude': 45.472641, 'longitude': 9.192283},
#     'main': {'latitude': 45.472463, 'longitude': 9.192251},
#     'roof': {'latitude': 45.472463, 'longitude': 9.192251}},
#    'link': '/v3/places/3dd96de10b2c4f29a3efb683',
#    'location': {'address': "Via dell'Annunciata 21",
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': "Via dell'Annunciata 21, 20121 Milano Lombardia",
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Lombardia'},
#    'name': 'Back to Work 24',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '9186545239204bda645a88bd',
#    'categories': [{'id': 19019,
#      'name': 'Vacation Rental',
#      'short_name': 'Vacation Rental',
#      'plural_name': 'Vacation Rentals',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 952,
#    'geocodes': {'drop_off': {'latitude': 45.472395, 'longitude': 9.185532},
#     'main': {'latitude': 45.472346, 'longitude': 9.185415},
#     'roof': {'latitude': 45.472346, 'longitude': 9.185415}},
#    'link': '/v3/places/9186545239204bda645a88bd',
#    'location': {'address': 'Via Pontaccio 17',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Pontaccio 17, 20121 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Lombardia'},
#    'name': 'ALTIDO Lovely Flat for 5 close to Sforzesco Castle',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '514d8d7fe4b06f827273f3e9',
#    'categories': [{'id': 17043,
#      'name': 'Clothing Store',
#      'short_name': 'Apparel',
#      'plural_name': 'Clothing Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 953,
#    'geocodes': {'drop_off': {'latitude': 45.456777, 'longitude': 9.194683},
#     'main': {'latitude': 45.456621, 'longitude': 9.194583},
#     'roof': {'latitude': 45.456621, 'longitude': 9.194583}},
#    'link': '/v3/places/514d8d7fe4b06f827273f3e9',
#    'location': {'address': 'Corso di Porta Romana 55',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Corso di Porta Romana 55, 20122 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Lombardia'},
#    'name': 'Five to nine',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4d502932747f6dcbb59ab2d4',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'short_name': 'Advertising Agency',
#      'plural_name': 'Advertising Agencies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1346,
#    'geocodes': {'drop_off': {'latitude': 45.466558, 'longitude': 9.172377},
#     'main': {'latitude': 45.466479, 'longitude': 9.172487},
#     'roof': {'latitude': 45.466479, 'longitude': 9.172487}},
#    'link': '/v3/places/4d502932747f6dcbb59ab2d4',
#    'location': {'address': 'Via Caradosso 8',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Caradosso 8, 20123 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Lombardia'},
#    'name': 'Close To Media SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4f8d9d12e4b013d9a56111ff',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1387,
#    'geocodes': {'drop_off': {'latitude': 45.465699, 'longitude': 9.171807},
#     'main': {'latitude': 45.46559, 'longitude': 9.171803},
#     'roof': {'latitude': 45.46559, 'longitude': 9.171803}},
#    'link': '/v3/places/4f8d9d12e4b013d9a56111ff',
#    'location': {'address': 'Corso Magenta 61',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Corso Magenta 61, Milano Lombardia',
#     'locality': 'Milano',
#     'region': 'Lombardia'},
#    'name': 'Cradle to Cradle',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '02af058fbb7a4ae5ab8d30ca',
#    'categories': [{'id': 11025,
#      'name': 'Child Care Service',
#      'short_name': 'Child Care',
#      'plural_name': 'Child Care Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1422,
#    'geocodes': {'drop_off': {'latitude': 45.466198, 'longitude': 9.207324},
#     'main': {'latitude': 45.466218, 'longitude': 9.207547},
#     'roof': {'latitude': 45.466218, 'longitude': 9.207547}},
#    'link': '/v3/places/02af058fbb7a4ae5ab8d30ca',
#    'location': {'address': 'Viale Premuda 38',
#     'address_extended': 'A',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Viale Premuda 38, 20129 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20129',
#     'region': 'Lombardia'},
#    'name': 'One To Three',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '3ff6dfc9c9ae460cd3074317',
#    'categories': [{'id': 19019,
#      'name': 'Vacation Rental',
#      'short_name': 'Vacation Rental',
#      'plural_name': 'Vacation Rentals',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1804,
#    'geocodes': {'drop_off': {'latitude': 45.457387, 'longitude': 9.16857},
#     'main': {'latitude': 45.457479, 'longitude': 9.168482},
#     'roof': {'latitude': 45.457479, 'longitude': 9.168482}},
#    'link': '/v3/places/3ff6dfc9c9ae460cd3074317',
#    'location': {'address': 'Via Andrea Solari 2',
#     'address_extended': 'A',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Andrea Solari 2, 20144 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20144',
#     'region': 'Lombardia'},
#    'name': 'ALTIDO Fabulous Family Apt for 4 with Terrace next to Park',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '63232a8da3272d7e30aab821',
#    'categories': [{'id': 13009,
#      'name': 'Cocktail Bar',
#      'short_name': 'Cocktail',
#      'plural_name': 'Cocktail Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1864,
#    'geocodes': {'drop_off': {'latitude': 45.451479, 'longitude': 9.173981},
#     'main': {'latitude': 45.451434, 'longitude': 9.17399},
#     'roof': {'latitude': 45.451434, 'longitude': 9.17399}},
#    'link': '/v3/places/63232a8da3272d7e30aab821',
#    'location': {'address': 'Ripa di Porta Ticinese 37',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Ripa di Porta Ticinese 37, 20143 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20143',
#     'region': 'Lombardia'},
#    'name': 'ADA Cocktail To Go',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4d3b0eaf979ea143766597fc',
#    'categories': [{'id': 17117,
#      'name': 'Sporting Goods Retail',
#      'short_name': 'Sporting Goods Retail',
#      'plural_name': 'Sporting Goods Retail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1907,
#    'geocodes': {'drop_off': {'latitude': 45.476719, 'longitude': 9.172531},
#     'main': {'latitude': 45.476699, 'longitude': 9.172696},
#     'roof': {'latitude': 45.476699, 'longitude': 9.172696}},
#    'link': '/v3/places/4d3b0eaf979ea143766597fc',
#    'location': {'address': 'Via Cagnola 10',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': 'Piazza Sempione',
#     'formatted_address': 'Via Cagnola 10 (Piazza Sempione), Milano Lombardia',
#     'locality': 'Milano',
#     'region': 'Lombardia'},
#    'name': 'Born to Run',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '512893a4e0e2b2424b49271c',
#    'categories': [{'id': 11003,
#      'name': 'Architecture Firm',
#      'short_name': 'Architecture Firm',
#      'plural_name': 'Architecture Firms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1968,
#    'geocodes': {'drop_off': {'latitude': 45.464654, 'longitude': 9.164403},
#     'main': {'latitude': 45.464609, 'longitude': 9.164559},
#     'roof': {'latitude': 45.464609, 'longitude': 9.164559}},
#    'link': '/v3/places/512893a4e0e2b2424b49271c',
#    'location': {'address': 'Viale San Michele del Carso 10',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Viale San Michele del Carso 10, 20144 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20144',
#     'region': 'Lombardia'},
#    'name': 'Design To Users SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': 'c762b4f100e6449e8c26279d',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1974,
#    'geocodes': {'main': {'latitude': 45.477643, 'longitude': 9.172818},
#     'roof': {'latitude': 45.477643, 'longitude': 9.172818}},
#    'link': '/v3/places/c762b4f100e6449e8c26279d',
#    'location': {'address': 'Via Luigi Cagnola 12',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Luigi Cagnola 12, 20154 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20154',
#     'region': 'Lombardia'},
#    'name': 'Osteria Ten To Ten',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '1a6a832edb36423bb453c6b4',
#    'categories': [{'id': 15023,
#      'name': 'Nutritionist',
#      'short_name': 'Nutritionist',
#      'plural_name': 'Nutritionists',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2011,
#    'geocodes': {'drop_off': {'latitude': 45.481003, 'longitude': 9.19872},
#     'main': {'latitude': 45.48116, 'longitude': 9.198794},
#     'roof': {'latitude': 45.48116, 'longitude': 9.198794}},
#    'link': '/v3/places/1a6a832edb36423bb453c6b4',
#    'location': {'address': 'Via Locatelli 2',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Locatelli 2, 20124 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20124',
#     'region': 'Lombardia'},
#    'name': 'Diet To Go',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '61a8095df54f7c01c185ee1c',
#    'categories': [{'id': 11041,
#      'name': 'Film Studio',
#      'short_name': 'Film Studio',
#      'plural_name': 'Film Studios',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#       'suffix': '.png'}},
#     {'id': 17038,
#      'name': 'Textiles Store',
#      'short_name': 'Textiles Store',
#      'plural_name': 'Textiles Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2092,
#    'geocodes': {'drop_off': {'latitude': 45.482722, 'longitude': 9.183491},
#     'main': {'latitude': 45.482618, 'longitude': 9.183352},
#     'roof': {'latitude': 45.482618, 'longitude': 9.183352}},
#    'link': '/v3/places/61a8095df54f7c01c185ee1c',
#    'location': {'address': 'Via Pietro Maroncelli 7',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Pietro Maroncelli 7, 20154 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20154',
#     'region': 'Lombardia'},
#    'name': 'Disc To Disc Productions SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4f7ed1dee5e8cf764f5044f7',
#    'categories': [{'id': 11039,
#      'name': 'Event Space',
#      'short_name': 'Event Space',
#      'plural_name': 'Event Spaces',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2104,
#    'geocodes': {'drop_off': {'latitude': 45.453282, 'longitude': 9.167507},
#     'main': {'latitude': 45.453372, 'longitude': 9.167429},
#     'roof': {'latitude': 45.453372, 'longitude': 9.167429}},
#    'link': '/v3/places/4f7ed1dee5e8cf764f5044f7',
#    'location': {'address': 'Via Tortona 18',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Tortona 18, 20144 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20144',
#     'region': 'Lombardia'},
#    'name': "Mayumi Yamada - La Tradizione dell'Oriente sbarca in Occidente/ Orient Tradition lands to West",
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4cc1ac8221a4f04da27f6555',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'short_name': 'Advertising Agency',
#      'plural_name': 'Advertising Agencies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2457,
#    'geocodes': {'main': {'latitude': 45.479323, 'longitude': 9.212613},
#     'roof': {'latitude': 45.479323, 'longitude': 9.212613}},
#    'link': '/v3/places/4cc1ac8221a4f04da27f6555',
#    'location': {'address': 'Via Plinio 11',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Plinio 11, 20129 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20129',
#     'region': 'Lombardia'},
#    'name': 'One To One Italia SRL',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4ba000f7f964a520825137e3',
#    'categories': [{'id': 10000,
#      'name': 'Arts and Entertainment',
#      'short_name': 'Arts & Entertainment',
#      'plural_name': 'Arts and Entertainment',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}},
#     {'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 2483,
#    'geocodes': {'drop_off': {'latitude': 45.460683, 'longitude': 9.15805},
#     'main': {'latitude': 45.460577, 'longitude': 9.158085},
#     'roof': {'latitude': 45.460577, 'longitude': 9.158085}},
#    'link': '/v3/places/4ba000f7f964a520825137e3',
#    'location': {'address': "Via Boni angolo Via vetta d'italia",
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': "Via Boni angolo Via vetta d'italia, 20144 Città metropolitana di Milano Lombardia",
#     'locality': 'Città metropolitana di Milano',
#     'postcode': '20144',
#     'region': 'Lombardia'},
#    'name': 'To Tap',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '5783b135498e62d44b7191b4',
#    'categories': [{'id': 10016,
#      'name': 'Exhibit',
#      'short_name': 'Exhibit',
#      'plural_name': 'Exhibits',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2500,
#    'geocodes': {'drop_off': {'latitude': 45.478266, 'longitude': 9.214312},
#     'main': {'latitude': 45.478164, 'longitude': 9.214227},
#     'roof': {'latitude': 45.478164, 'longitude': 9.214227}},
#    'link': '/v3/places/5783b135498e62d44b7191b4',
#    'location': {'address': 'Via Plinio 17',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Plinio 17, 20129 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20129',
#     'region': 'Lombardia'},
#    'name': 'appartamento TO DO',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4f7dc2a46b7478c17cb72131',
#    'categories': [{'id': 11039,
#      'name': 'Event Space',
#      'short_name': 'Event Space',
#      'plural_name': 'Event Spaces',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2511,
#    'geocodes': {'drop_off': {'latitude': 45.451898, 'longitude': 9.163132},
#     'main': {'latitude': 45.452017, 'longitude': 9.163098},
#     'roof': {'latitude': 45.452017, 'longitude': 9.163098}},
#    'link': '/v3/places/4f7dc2a46b7478c17cb72131',
#    'location': {'address': 'Via Tortona 31',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Tortona 31, 20144 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20144',
#     'region': 'Lombardia'},
#    'name': 'Passing on Project - Touch to turn light into delight supported by TOSHIBA',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4df070afd4c04d0392c5fb29',
#    'categories': [{'id': 18028,
#      'name': 'Yoga Studio',
#      'short_name': 'Yoga Studio',
#      'plural_name': 'Yoga Studios',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2565,
#    'geocodes': {'drop_off': {'latitude': 45.463281, 'longitude': 9.156582},
#     'main': {'latitude': 45.463123, 'longitude': 9.156634},
#     'roof': {'latitude': 45.463123, 'longitude': 9.156634}},
#    'link': '/v3/places/4df070afd4c04d0392c5fb29',
#    'location': {'address': 'Via Pirandello 4a',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Pirandello 4a, Milano Lombardia',
#     'locality': 'Milano',
#     'region': 'Lombardia'},
#    'name': 'To Be Pilates',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '232422e89efc4e96652eeab6',
#    'categories': [{'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'short_name': 'Fast Food',
#      'plural_name': 'Fast Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2666,
#    'geocodes': {'drop_off': {'latitude': 45.474668, 'longitude': 9.220379},
#     'main': {'latitude': 45.474544, 'longitude': 9.220429},
#     'roof': {'latitude': 45.474544, 'longitude': 9.220429}},
#    'link': '/v3/places/232422e89efc4e96652eeab6',
#    'location': {'address': 'Via Pascoli 18',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Pascoli 18, 20129 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20129',
#     'region': 'Lombardia'},
#    'name': 'Takeaway Diet To Go',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '59f107e7ad454b82751c2b3b',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 2764,
#    'geocodes': {'drop_off': {'latitude': 45.480733, 'longitude': 9.215893},
#     'main': {'latitude': 45.480854, 'longitude': 9.215955},
#     'roof': {'latitude': 45.480854, 'longitude': 9.215955}},
#    'link': '/v3/places/59f107e7ad454b82751c2b3b',
#    'location': {'address': 'Via Paracelso 1',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Paracelso 1, 20129 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20129',
#     'region': 'Lombardia'},
#    'name': 'Time to Poke',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '5a914a968d7844271a6f1119',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 2914,
#    'geocodes': {'main': {'latitude': 45.485791, 'longitude': 9.210898},
#     'roof': {'latitude': 45.485791, 'longitude': 9.210898}},
#    'link': '/v3/places/5a914a968d7844271a6f1119',
#    'location': {'address': 'Viale Andrea Doria 17',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Viale Andrea Doria 17, 20124 Milano Lombardia',
#     'locality': 'Milano',
#     'postcode': '20124',
#     'region': 'Lombardia'},
#    'name': 'Studio From Trauma To Wellness',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': 'c27cde3f007b45e06b74fd8a',
#    'categories': [{'id': 12094,
#      'name': 'Residential Building',
#      'short_name': 'Residence',
#      'plural_name': 'Residential Buildings',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/home_',
#       'suffix': '.png'}},
#     {'id': 19009,
#      'name': 'Lodging',
#      'short_name': 'Lodging',
#      'plural_name': 'Lodging',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 407,
#    'geocodes': {'main': {'latitude': 45.461785, 'longitude': 9.18566},
#     'roof': {'latitude': 45.461785, 'longitude': 9.18566}},
#    'link': '/v3/places/c27cde3f007b45e06b74fd8a',
#    'location': {'address': 'Via Valpetrosa 10',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Valpetrosa 10, 20123 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Milano'},
#    'name': 'New Apartment Close to Duomo',
#    'related_places': {}},
#   {'fsq_id': 'd2134bcea06a46f9dee8daf0',
#    'categories': [{'id': 19019,
#      'name': 'Vacation Rental',
#      'short_name': 'Vacation Rental',
#      'plural_name': 'Vacation Rentals',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 407,
#    'geocodes': {'drop_off': {'latitude': 45.461845, 'longitude': 9.185686},
#     'main': {'latitude': 45.461785, 'longitude': 9.18566},
#     'roof': {'latitude': 45.461785, 'longitude': 9.18566}},
#    'link': '/v3/places/d2134bcea06a46f9dee8daf0',
#    'location': {'address': 'Via Valpetrosa 10',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Valpetrosa 10, 20123 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Milano'},
#    'name': 'Mansard very close to Duomo',
#    'related_places': {}},
#   {'fsq_id': '70c32c915f12479eab3b5f83',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 413,
#    'geocodes': {'drop_off': {'latitude': 45.461877, 'longitude': 9.185612},
#     'main': {'latitude': 45.461777, 'longitude': 9.185568},
#     'roof': {'latitude': 45.461777, 'longitude': 9.185568}},
#    'link': '/v3/places/70c32c915f12479eab3b5f83',
#    'location': {'address': 'Via Valpetrosa 10, Milano Centro',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Valpetrosa 10, Milano Centro, Milano Milano',
#     'locality': 'Milano',
#     'region': 'Milano'},
#    'name': 'Apartment very close to Duomo',
#    'related_places': {}},
#   {'fsq_id': 'a4df33be32be4fc2d4eda675',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'short_name': 'Advertising Agency',
#      'plural_name': 'Advertising Agencies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 716,
#    'geocodes': {'drop_off': {'latitude': 45.461208, 'longitude': 9.181514},
#     'main': {'latitude': 45.461208, 'longitude': 9.181423},
#     'roof': {'latitude': 45.461208, 'longitude': 9.181423}},
#    'link': '/v3/places/a4df33be32be4fc2d4eda675',
#    'location': {'address': 'Via San Sisto 8',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via San Sisto 8, 20123 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20123',
#     'region': 'Milano'},
#    'name': 'To Be Advertising SRL',
#    'related_places': {}},
#   {'fsq_id': '4ccedadcdb3b4dd3ea3690a3',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'short_name': 'Advertising Agency',
#      'plural_name': 'Advertising Agencies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}},
#     {'id': 17112,
#      'name': 'Print Store',
#      'short_name': 'Print Store',
#      'plural_name': 'Print Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 743,
#    'geocodes': {'drop_off': {'latitude': 45.467141, 'longitude': 9.198001},
#     'main': {'latitude': 45.467114, 'longitude': 9.198142},
#     'roof': {'latitude': 45.467114, 'longitude': 9.198142}},
#    'link': '/v3/places/4ccedadcdb3b4dd3ea3690a3',
#    'location': {'address': 'corso Venezia 3',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'corso Venezia 3, 20121 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20121',
#     'region': 'Milano'},
#    'name': 'Time To Work Società Coop',
#    'related_places': {}},
#   {'fsq_id': 'fffb518f9e1b4f397d0843e7',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 775,
#    'geocodes': {'drop_off': {'latitude': 45.461426, 'longitude': 9.198424},
#     'main': {'latitude': 45.461455, 'longitude': 9.198608},
#     'roof': {'latitude': 45.461455, 'longitude': 9.198608}},
#    'link': '/v3/places/fffb518f9e1b4f397d0843e7',
#    'location': {'address': 'Via della Guastalla 5',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via della Guastalla 5, 20122 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Milano'},
#    'name': 'Studio Toffoloni dei Dottori Commercialisti Associati Gianandrea To',
#    'related_places': {}},
#   {'fsq_id': 'b846add09a4b4b965634d5a8',
#    'categories': [{'id': 11086,
#      'name': 'General Contractor',
#      'short_name': 'General Contractor',
#      'plural_name': 'General Contractors',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 977,
#    'geocodes': {'drop_off': {'latitude': 45.456374, 'longitude': 9.183605},
#     'main': {'latitude': 45.456447, 'longitude': 9.183776},
#     'roof': {'latitude': 45.456447, 'longitude': 9.183776}},
#    'link': '/v3/places/b846add09a4b4b965634d5a8',
#    'location': {'address': 'Via Santa Croce 4',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Santa Croce 4, 20122 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Milano'},
#    'name': 'Ready To Fly SRL',
#    'related_places': {}},
#   {'fsq_id': '9e46027d02d0416436d67214',
#    'categories': [],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1237,
#    'geocodes': {'drop_off': {'latitude': 45.470389, 'longitude': 9.202719},
#     'main': {'latitude': 45.470464, 'longitude': 9.202708},
#     'roof': {'latitude': 45.470464, 'longitude': 9.202708}},
#    'link': '/v3/places/9e46027d02d0416436d67214',
#    'location': {'address': 'Via Cappuccini 6',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Cappuccini 6, 20122 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Milano'},
#    'name': 'Key To Work Impresa Sociale SRL',
#    'related_places': {}},
#   {'fsq_id': 'f5edce9e0c7d4fd4f17c5c8e',
#    'categories': [{'id': 11001,
#      'name': 'Advertising Agency',
#      'short_name': 'Advertising Agency',
#      'plural_name': 'Advertising Agencies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 1320,
#    'geocodes': {'drop_off': {'latitude': 45.469405, 'longitude': 9.204726},
#     'main': {'latitude': 45.469508, 'longitude': 9.204716},
#     'roof': {'latitude': 45.469508, 'longitude': 9.204716}},
#    'link': '/v3/places/f5edce9e0c7d4fd4f17c5c8e',
#    'location': {'address': 'Via Gioacchino Rossini 3',
#     'admin_region': 'Lombardia',
#     'country': 'IT',
#     'formatted_address': 'Via Gioacchino Rossini 3, 20122 Milano Milano',
#     'locality': 'Milano',
#     'postcode': '20122',
#     'region': 'Milano'},
#    'name': 'To Be Advertising SRL',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 45.46427,
#      'longitude': 9.18951},
#     'radius': 8743}}}}

# %%
def get_places(lat, lng, radius, categories=None):
    '''
    Fetch places (attractions, events, etc.) from the Google Places API based on location and radius.
    '''

    api_url = "https://places.googleapis.com/v1/places:searchNearby"

    # Define the JSON body of the request
    request_body = {
        "locationRestriction": {
            "circle": {
                "center": {
                    "latitude": float(lat),
                    "longitude": float(lng)
                },
                "radius": int(radius * 1000)  # Convert radius to meters
            }
        },
        "includedTypes": [
            "art_gallery",
            "monument",
            "museum",
            "cultural_landmark",
            "historical_place",
            "church",
            "mosque",
            "hindu_temple",
            "synagogue",
            "wildlife_park",
            "park",
            "zoo",
            "plaza",
            "aquarium"
        ],
        "maxResultCount": 20,
        "rankPreference": "POPULARITY"  # Removed as it's not supported in Nearby Search (New)
    }

    # Apply categories filter if provided
    if categories:
        request_body["includedTypes"] = categories

    # FieldMask to specify the fields to return (displayName is essential)
    field_mask = "places.name,places.displayName,places.shortFormattedAddress,places.location,places.types,places.rating,places.regularOpeningHours"

    # Headers, including the API key and FieldMask
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key":  GOOGLE_PLACES_API_KEY,
        "X-Goog-FieldMask": field_mask,
    }

    try:
        # Make the POST request
        response = requests.post(api_url, json=request_body, headers=headers)

        # Check if the response status is OK
        if response.status_code == 200:
            return response.json()
        else:
            return {'error': 'Failed to fetch data from Places API', 'status_code': response.status_code}
    except Exception as e:
        return {'error': str(e)}

# %%
lat =45.461355
lng = 9.186311
radius = 5

get_places(lat,lng,radius)
# Out:
# {'places': [{'name': 'places/ChIJoTZGw67GhkcREy4aECdOf6s',
#    'types': ['tourist_attraction',
#     'church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.464097599999995, 'longitude': 9.1919265},
#    'rating': 4.8,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 0},
#       'close': {'day': 0, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 9, 'minute': 0},
#       'close': {'day': 1, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 9, 'minute': 0},
#       'close': {'day': 2, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 9, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 9, 'minute': 0},
#       'close': {'day': 4, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 9, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 0},
#       'close': {'day': 6, 'hour': 19, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Tuesday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Wednesday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Thursday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Friday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Saturday: 9:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Sunday: 9:00\u202fAM\u2009–\u20097:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T18:00:00Z'},
#    'displayName': {'text': 'Duomo di Milano', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Milan Cathedral, P.za del Duomo, Milano'},
#   {'name': 'places/ChIJPXupDrb8hkcRm8JyxGbdVmU',
#    'types': ['tourist_attraction',
#     'historical_place',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4704762, 'longitude': 9.1793325},
#    'rating': 4.7,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0},
#       'close': {'day': 0, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 1, 'hour': 7, 'minute': 0},
#       'close': {'day': 1, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 7, 'minute': 0},
#       'close': {'day': 2, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 3, 'hour': 7, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 4, 'hour': 7, 'minute': 0},
#       'close': {'day': 4, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 5, 'hour': 7, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 6, 'hour': 7, 'minute': 0},
#       'close': {'day': 6, 'hour': 19, 'minute': 30}}],
#     'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Tuesday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Wednesday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Thursday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Friday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Saturday: 7:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Sunday: 7:00\u202fAM\u2009–\u20097:30\u202fPM'],
#     'nextCloseTime': '2024-11-25T18:30:00Z'},
#    'displayName': {'text': 'Sforzesco Castle', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Piazza Castello, Milano'},
#   {'name': 'places/ChIJz7dBqkfBhkcRFcbFfk20vPs',
#    'types': ['historical_landmark',
#     'tourist_attraction',
#     'historical_place',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.475692699999996, 'longitude': 9.1724514},
#    'rating': 4.7,
#    'displayName': {'text': 'Arco della Pace', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Piazza Sempione, Milano'},
#   {'name': 'places/ChIJgxy_RFrBhkcRWVrH08TNW-0',
#    'types': ['tourist_attraction',
#     'church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.465962999999995,
#     'longitude': 9.170962099999999},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 30},
#       'close': {'day': 0, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 0, 'hour': 15, 'minute': 0},
#       'close': {'day': 0, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 7, 'minute': 0},
#       'close': {'day': 1, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 15, 'minute': 0},
#       'close': {'day': 1, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 7, 'minute': 0},
#       'close': {'day': 2, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 15, 'minute': 0},
#       'close': {'day': 2, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 3, 'hour': 7, 'minute': 0},
#       'close': {'day': 3, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 15, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 4, 'hour': 7, 'minute': 0},
#       'close': {'day': 4, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 15, 'minute': 0},
#       'close': {'day': 4, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 5, 'hour': 7, 'minute': 0},
#       'close': {'day': 5, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 15, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 6, 'hour': 7, 'minute': 0},
#       'close': {'day': 6, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 15, 'minute': 0},
#       'close': {'day': 6, 'hour': 19, 'minute': 30}}],
#     'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Tuesday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Wednesday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Thursday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Friday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Saturday: 7:00\u202fAM\u2009–\u20091:00\u202fPM, 3:00\u2009–\u20097:30\u202fPM',
#      'Sunday: 7:30\u202fAM\u2009–\u200912:30\u202fPM, 3:00\u2009–\u20099:00\u202fPM'],
#     'nextOpenTime': '2024-11-25T14:00:00Z'},
#    'displayName': {'text': 'Basilica di Santa Maria delle Grazie',
#     'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Giuseppe Antonio Sassi, 3, Milano'},
#   {'name': 'places/ChIJH05-WBHuhkcRNjexLI56Nhs',
#    'types': ['art_gallery',
#     'tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.471954499999995, 'longitude': 9.1878145},
#    'rating': 4.7,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 30},
#       'close': {'day': 0, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 8, 'minute': 30},
#       'close': {'day': 2, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 8, 'minute': 30},
#       'close': {'day': 3, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 8, 'minute': 30},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 8, 'minute': 30},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 8, 'minute': 30},
#       'close': {'day': 6, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: 8:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Wednesday: 8:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Thursday: 8:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Friday: 8:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Saturday: 8:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Sunday: 8:30\u202fAM\u2009–\u20096:00\u202fPM'],
#     'nextOpenTime': '2024-11-26T07:30:00Z'},
#    'displayName': {'text': 'Pinacoteca di Brera', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Brera, 28, Milano'},
#   {'name': 'places/ChIJhSUDc4_DhkcRuPJwjgkJgME',
#    'types': ['tourist_attraction',
#     'historical_landmark',
#     'historical_place',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4516133, 'longitude': 9.1740098},
#    'rating': 4.5,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 1, 'hour': 9, 'minute': 0},
#       'close': {'day': 1, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 14, 'minute': 0},
#       'close': {'day': 1, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 9, 'minute': 0},
#       'close': {'day': 2, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 14, 'minute': 0},
#       'close': {'day': 2, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 9, 'minute': 0},
#       'close': {'day': 3, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 14, 'minute': 0},
#       'close': {'day': 3, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 9, 'minute': 0},
#       'close': {'day': 4, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 14, 'minute': 0},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 9, 'minute': 0},
#       'close': {'day': 5, 'hour': 13, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 14, 'minute': 0},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 9:00\u202fAM\u2009–\u20091:00\u202fPM, 2:00\u2009–\u20096:00\u202fPM',
#      'Tuesday: 9:00\u202fAM\u2009–\u20091:00\u202fPM, 2:00\u2009–\u20096:00\u202fPM',
#      'Wednesday: 9:00\u202fAM\u2009–\u20091:00\u202fPM, 2:00\u2009–\u20096:00\u202fPM',
#      'Thursday: 9:00\u202fAM\u2009–\u20091:00\u202fPM, 2:00\u2009–\u20096:00\u202fPM',
#      'Friday: 9:00\u202fAM\u2009–\u20091:00\u202fPM, 2:00\u2009–\u20096:00\u202fPM',
#      'Saturday: Closed',
#      'Sunday: Closed'],
#     'nextCloseTime': '2024-11-25T17:00:00Z'},
#    'displayName': {'text': 'Naviglio Grande', 'languageCode': 'it'},
#    'shortFormattedAddress': 'Alzaia Naviglio Grande, Milano'},
#   {'name': 'places/ChIJm-5swlnBhkcRkuvlGcqPRXI',
#    'types': ['tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.462808, 'longitude': 9.1707478},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 30},
#       'close': {'day': 0, 'hour': 18, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 9, 'minute': 30},
#       'close': {'day': 2, 'hour': 17, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 9, 'minute': 30},
#       'close': {'day': 3, 'hour': 17, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 9, 'minute': 30},
#       'close': {'day': 4, 'hour': 17, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 9, 'minute': 30},
#       'close': {'day': 5, 'hour': 17, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 30},
#       'close': {'day': 6, 'hour': 18, 'minute': 30}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: 9:30\u202fAM\u2009–\u20095:00\u202fPM',
#      'Wednesday: 9:30\u202fAM\u2009–\u20095:00\u202fPM',
#      'Thursday: 9:30\u202fAM\u2009–\u20095:00\u202fPM',
#      'Friday: 9:30\u202fAM\u2009–\u20095:00\u202fPM',
#      'Saturday: 9:30\u202fAM\u2009–\u20096:30\u202fPM',
#      'Sunday: 9:30\u202fAM\u2009–\u20096:30\u202fPM'],
#     'nextOpenTime': '2024-11-26T08:30:00Z'},
#    'displayName': {'text': 'Leonardo da Vinci Museum of Science and Technology',
#     'languageCode': 'en'},
#    'shortFormattedAddress': 'Via San Vittore, 21, Milano'},
#   {'name': 'places/ChIJWUblrUjBhkcRtpP5ICHdu7g',
#    'types': ['park',
#     'tourist_attraction',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4720981, 'longitude': 9.177224299999999},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 30},
#       'close': {'day': 0, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 6, 'minute': 30},
#       'close': {'day': 1, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 6, 'minute': 30},
#       'close': {'day': 2, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 6, 'minute': 30},
#       'close': {'day': 3, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 6, 'minute': 30},
#       'close': {'day': 4, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 6, 'minute': 30},
#       'close': {'day': 5, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 6, 'minute': 30},
#       'close': {'day': 6, 'hour': 21, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Tuesday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Wednesday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Thursday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Friday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Saturday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Sunday: 6:30\u202fAM\u2009–\u20099:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T20:00:00Z'},
#    'displayName': {'text': 'Parco Sempione', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Milan'},
#   {'name': 'places/ChIJ16AE-J7GhkcRnxchwJ_WRRU',
#    'types': ['tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4443804, 'longitude': 9.205300099999999},
#    'rating': 4.2,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 0},
#       'close': {'day': 0, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 10, 'minute': 0},
#       'close': {'day': 1, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 10, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 0},
#       'close': {'day': 4, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 10, 'minute': 0},
#       'close': {'day': 6, 'hour': 19, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Tuesday: Closed',
#      'Wednesday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Thursday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Friday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Saturday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Sunday: 10:00\u202fAM\u2009–\u20097:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T18:00:00Z'},
#    'displayName': {'text': 'Fondazione Prada', 'languageCode': 'en'},
#    'shortFormattedAddress': 'L.go Isarco, 2, Milano'},
#   {'name': 'places/ChIJCfxX3lbBhkcRY78V8stFXio',
#    'types': ['tourist_attraction',
#     'church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.462329200000006, 'longitude': 9.175612},
#    'rating': 4.7,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 15, 'minute': 0},
#       'close': {'day': 0, 'hour': 17, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 9, 'minute': 30},
#       'close': {'day': 1, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 1, 'hour': 14, 'minute': 30},
#       'close': {'day': 1, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 9, 'minute': 30},
#       'close': {'day': 2, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 14, 'minute': 30},
#       'close': {'day': 2, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 9, 'minute': 30},
#       'close': {'day': 3, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 3, 'hour': 14, 'minute': 30},
#       'close': {'day': 3, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 9, 'minute': 30},
#       'close': {'day': 4, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 4, 'hour': 14, 'minute': 30},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 9, 'minute': 30},
#       'close': {'day': 5, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 5, 'hour': 14, 'minute': 30},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 30},
#       'close': {'day': 6, 'hour': 12, 'minute': 30}},
#      {'open': {'day': 6, 'hour': 14, 'minute': 30},
#       'close': {'day': 6, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Tuesday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Wednesday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Thursday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Friday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Saturday: 9:30\u202fAM\u2009–\u200912:30\u202fPM, 2:30\u2009–\u20096:00\u202fPM',
#      'Sunday: 3:00\u2009–\u20095:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T17:00:00Z'},
#    'displayName': {'text': "Basilica of Sant'Ambrogio", 'languageCode': 'en'},
#    'shortFormattedAddress': "Piazza Sant'Ambrogio, 15, Milano"},
#   {'name': 'places/ChIJ76jHT1rBhkcRhv_9lZv4uG0',
#    'types': ['museum',
#     'tourist_attraction',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4661853, 'longitude': 9.170600499999999},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 15},
#       'close': {'day': 0, 'hour': 18, 'minute': 45}},
#      {'open': {'day': 2, 'hour': 8, 'minute': 15},
#       'close': {'day': 2, 'hour': 18, 'minute': 45}},
#      {'open': {'day': 3, 'hour': 8, 'minute': 15},
#       'close': {'day': 3, 'hour': 18, 'minute': 45}},
#      {'open': {'day': 4, 'hour': 8, 'minute': 15},
#       'close': {'day': 4, 'hour': 18, 'minute': 45}},
#      {'open': {'day': 5, 'hour': 8, 'minute': 15},
#       'close': {'day': 5, 'hour': 18, 'minute': 45}},
#      {'open': {'day': 6, 'hour': 8, 'minute': 15},
#       'close': {'day': 6, 'hour': 18, 'minute': 45}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: 8:15\u202fAM\u2009–\u20096:45\u202fPM',
#      'Wednesday: 8:15\u202fAM\u2009–\u20096:45\u202fPM',
#      'Thursday: 8:15\u202fAM\u2009–\u20096:45\u202fPM',
#      'Friday: 8:15\u202fAM\u2009–\u20096:45\u202fPM',
#      'Saturday: 8:15\u202fAM\u2009–\u20096:45\u202fPM',
#      'Sunday: 8:15\u202fAM\u2009–\u20096:45\u202fPM'],
#     'nextOpenTime': '2024-11-26T07:15:00Z'},
#    'displayName': {'text': "Leonardo's Last Supper Museum",
#     'languageCode': 'en'},
#    'shortFormattedAddress': 'Piazza di Santa Maria delle Grazie, 2, Milano'},
#   {'name': 'places/ChIJwcLyGObDhkcRd4Ay1dlKE3I',
#    'types': ['tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4515435, 'longitude': 9.1615384},
#    'rating': 4.4,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 30},
#       'close': {'day': 0, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 1, 'hour': 14, 'minute': 30},
#       'close': {'day': 1, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 9, 'minute': 30},
#       'close': {'day': 2, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 3, 'hour': 9, 'minute': 30},
#       'close': {'day': 3, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 4, 'hour': 9, 'minute': 30},
#       'close': {'day': 4, 'hour': 22, 'minute': 30}},
#      {'open': {'day': 5, 'hour': 9, 'minute': 30},
#       'close': {'day': 5, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 30},
#       'close': {'day': 6, 'hour': 22, 'minute': 30}}],
#     'weekdayDescriptions': ['Monday: 2:30\u2009–\u20097:30\u202fPM',
#      'Tuesday: 9:30\u202fAM\u2009–\u20097:30\u202fPM',
#      'Wednesday: 9:30\u202fAM\u2009–\u20097:30\u202fPM',
#      'Thursday: 9:30\u202fAM\u2009–\u200910:30\u202fPM',
#      'Friday: 9:30\u202fAM\u2009–\u20097:30\u202fPM',
#      'Saturday: 9:30\u202fAM\u2009–\u200910:30\u202fPM',
#      'Sunday: 9:30\u202fAM\u2009–\u20097:30\u202fPM'],
#     'nextCloseTime': '2024-11-25T18:30:00Z'},
#    'displayName': {'text': 'Mudec', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Tortona, 56, Milano'},
#   {'name': 'places/ChIJoXV1xa7GhkcRgWMIumOeV90',
#    'types': ['tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.463131399999995, 'longitude': 9.1911569},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 0},
#       'close': {'day': 0, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 2, 'hour': 10, 'minute': 0},
#       'close': {'day': 2, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 3, 'hour': 10, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 0},
#       'close': {'day': 4, 'hour': 22, 'minute': 30}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 30}},
#      {'open': {'day': 6, 'hour': 10, 'minute': 0},
#       'close': {'day': 6, 'hour': 19, 'minute': 30}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: 10:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Wednesday: 10:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Thursday: 10:00\u202fAM\u2009–\u200910:30\u202fPM',
#      'Friday: 10:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Saturday: 10:00\u202fAM\u2009–\u20097:30\u202fPM',
#      'Sunday: 10:00\u202fAM\u2009–\u20097:30\u202fPM'],
#     'nextOpenTime': '2024-11-26T09:00:00Z'},
#    'displayName': {'text': 'Palazzo Reale di Milano', 'languageCode': 'it'},
#    'shortFormattedAddress': 'P.za del Duomo, 12, Milano'},
#   {'name': 'places/ChIJF0JA-__DhkcRJEJ3Zfbs96Q',
#    'types': ['historical_landmark',
#     'historical_place',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4582477, 'longitude': 9.181058},
#    'rating': 4.4,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 0, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: Open 24 hours',
#      'Tuesday: Open 24 hours',
#      'Wednesday: Open 24 hours',
#      'Thursday: Open 24 hours',
#      'Friday: Open 24 hours',
#      'Saturday: Open 24 hours',
#      'Sunday: Open 24 hours']},
#    'displayName': {'text': 'Colonne di San Lorenzo', 'languageCode': 'it'},
#    'shortFormattedAddress': 'Corso di Porta Ticinese, Milano'},
#   {'name': 'places/ChIJRwVc7UXBhkcRIlGMal_aWHU',
#    'types': ['museum',
#     'cultural_center',
#     'performing_arts_theater',
#     'event_venue',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.472232999999996,
#     'longitude': 9.173606999999999},
#    'rating': 4.5,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 30},
#       'close': {'day': 0, 'hour': 20, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 10, 'minute': 30},
#       'close': {'day': 2, 'hour': 20, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 10, 'minute': 30},
#       'close': {'day': 3, 'hour': 20, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 30},
#       'close': {'day': 4, 'hour': 20, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 30},
#       'close': {'day': 5, 'hour': 20, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 10, 'minute': 30},
#       'close': {'day': 6, 'hour': 20, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: 10:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Wednesday: 10:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Thursday: 10:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Friday: 10:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Saturday: 10:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Sunday: 10:30\u202fAM\u2009–\u20098:00\u202fPM'],
#     'nextOpenTime': '2024-11-26T09:30:00Z'},
#    'displayName': {'text': 'Triennale di Milano', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Viale Emilio Alemagna, 6, Milano'},
#   {'name': 'places/ChIJhfp35qXGhkcR_dPp7rKmopg',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.462416600000005, 'longitude': 9.1955412},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 30},
#       'close': {'day': 0, 'hour': 12, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 8, 'minute': 0},
#       'close': {'day': 1, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 8, 'minute': 0},
#       'close': {'day': 2, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 8, 'minute': 0},
#       'close': {'day': 3, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 8, 'minute': 0},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 8, 'minute': 0},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 30},
#       'close': {'day': 6, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 8:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Tuesday: 8:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Wednesday: 8:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Thursday: 8:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Friday: 8:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Saturday: 9:30\u202fAM\u2009–\u20096:00\u202fPM',
#      'Sunday: 9:30\u202fAM\u2009–\u200912:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T17:00:00Z'},
#    'displayName': {'text': 'Santuario di San Bernardino alle Ossa',
#     'languageCode': 'en'},
#    'shortFormattedAddress': 'Piazza Santo Stefano, Milano'},
#   {'name': 'places/ChIJ9Yp6EcbBhkcRrVOdLrFGkuA',
#    'types': ['museum',
#     'tourist_attraction',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4933896, 'longitude': 9.1726722},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 30},
#       'close': {'day': 0, 'hour': 18, 'minute': 30}},
#      {'open': {'day': 1, 'hour': 10, 'minute': 0},
#       'close': {'day': 1, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 10, 'minute': 0},
#       'close': {'day': 2, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 10, 'minute': 0},
#       'close': {'day': 3, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 0},
#       'close': {'day': 4, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 0},
#       'close': {'day': 5, 'hour': 19, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 9, 'minute': 30},
#       'close': {'day': 6, 'hour': 20, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Tuesday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Wednesday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Thursday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Friday: 10:00\u202fAM\u2009–\u20097:00\u202fPM',
#      'Saturday: 9:30\u202fAM\u2009–\u20098:00\u202fPM',
#      'Sunday: 9:30\u202fAM\u2009–\u20096:30\u202fPM'],
#     'nextCloseTime': '2024-11-25T18:00:00Z'},
#    'displayName': {'text': 'Titanic: An Immersive Voyage - Milano',
#     'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Valtellina, 5, Milano'},
#   {'name': 'places/ChIJn8qyiKzGhkcRbtP7f16_hsw',
#    'types': ['tourist_attraction',
#     'museum',
#     'library',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4634791, 'longitude': 9.1857881},
#    'rating': 4.6,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 0},
#       'close': {'day': 0, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 10, 'minute': 0},
#       'close': {'day': 1, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 10, 'minute': 0},
#       'close': {'day': 2, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 0},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 0},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 10, 'minute': 0},
#       'close': {'day': 6, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Tuesday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Wednesday: Closed',
#      'Thursday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Friday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Saturday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Sunday: 10:00\u202fAM\u2009–\u20096:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T17:00:00Z'},
#    'displayName': {'text': 'Pinacoteca Ambrosiana', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Piazza Pio XI, 2, Milano'},
#   {'name': 'places/ChIJn2UxgrvGhkcRNLCIIIOoylM',
#    'types': ['tourist_attraction',
#     'museum',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4689726, 'longitude': 9.2021391},
#    'rating': 4.7,
#    'regularOpeningHours': {'openNow': False,
#     'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 0},
#       'close': {'day': 0, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 10, 'minute': 0},
#       'close': {'day': 3, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 10, 'minute': 0},
#       'close': {'day': 4, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 10, 'minute': 0},
#       'close': {'day': 5, 'hour': 18, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 10, 'minute': 0},
#       'close': {'day': 6, 'hour': 18, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: Closed',
#      'Tuesday: Closed',
#      'Wednesday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Thursday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Friday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Saturday: 10:00\u202fAM\u2009–\u20096:00\u202fPM',
#      'Sunday: 10:00\u202fAM\u2009–\u20096:00\u202fPM'],
#     'nextOpenTime': '2024-11-27T09:00:00Z'},
#    'displayName': {'text': 'Villa Necchi Campiglio', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Mozart, 14, Milano'},
#   {'name': 'places/ChIJQ6I4eLjGhkcRFSEHiJxJ6mA',
#    'types': ['park',
#     'tourist_attraction',
#     'point_of_interest',
#     'establishment'],
#    'location': {'latitude': 45.4744489, 'longitude': 9.1993654},
#    'rating': 4.4,
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 30},
#       'close': {'day': 0, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 6, 'minute': 30},
#       'close': {'day': 1, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 6, 'minute': 30},
#       'close': {'day': 2, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 6, 'minute': 30},
#       'close': {'day': 3, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 6, 'minute': 30},
#       'close': {'day': 4, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 6, 'minute': 30},
#       'close': {'day': 5, 'hour': 21, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 6, 'minute': 30},
#       'close': {'day': 6, 'hour': 21, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Tuesday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Wednesday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Thursday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Friday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Saturday: 6:30\u202fAM\u2009–\u20099:00\u202fPM',
#      'Sunday: 6:30\u202fAM\u2009–\u20099:00\u202fPM'],
#     'nextCloseTime': '2024-11-25T20:00:00Z'},
#    'displayName': {'text': 'Indro Montanelli Gardens', 'languageCode': 'en'},
#    'shortFormattedAddress': 'Via Palestro, Milano'}]}

# %%
def get_tiqets_products(lat, lng, radius, page=1, page_size=100):
    """
    Fetch products (attractions, events, etc.) from the Tiqets API based on location and radius.

    Args:
        lat (float): Latitude of the location.
        lng (float): Longitude of the location.
        radius (int): Maximum search radius in meters.
        page (int, optional): Page number for pagination. Defaults to 1.
        page_size (int, optional): Number of results per page. Defaults to 100.

    Returns:
        dict: JSON response from Tiqets API with product data.
    """
    api_url = "https://api.tiqets.com/v2/products"

    # Headers for the API request
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Token {TIQETS_API_KEY}",  # Using the API key from settings
    }

    # Parameters for the API request
    params = {
        "lat": lat,
        "lng": lng,
        "max_distance": radius,
        "sort": "popularity desc",  # Sorting by popularity in descending order
        "page": page,
        "page_size": page_size,
    }

    try:
        # Make the GET request to the Tiqets API
        response = requests.get(api_url, headers=headers, params=params)

        # Check if the response status is OK
        if response.status_code == 200:
            return response.json()  # Return the JSON response with the data
        else:
            return {'error': 'Failed to fetch data from Tiqets API', 'status_code': response.status_code}
    except Exception as e:
        return {'error': str(e)}

# %%
lat =45.461355
lng = 9.186311
radius = 5

get_tiqets_products(lat,lng,radius)
# Out:
# {'success': True,
#  'api_version': {'major': 2, 'minor': 5, 'patch': 'v241125-1433.1'},
#  'products': [{'id': '974232',
#    'language': 'en',
#    'title': 'Duomo di Milano, Rooftops & Museum: Entry Ticket',
#    'city_id': '71749',
#    'country_id': '50109',
#    'tag_ids': ['444', '1234', '1198', '1363', '1192', '1185', '1235', '1188'],
#    'images': [{'small': 'https://aws-tiqets-cdn.imgix.net/images/content/bff1f116bfdf4d7ab2bbeadd82b0a679.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=6e4299016c89b857bd75e903509dd0f8',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/bff1f116bfdf4d7ab2bbeadd82b0a679.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=046c3e3f1dc796ad4d036bca238ca6b4',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/bff1f116bfdf4d7ab2bbeadd82b0a679.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=c0bc2295109a78e3a73b5bfdda8c7a59',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/bff1f116bfdf4d7ab2bbeadd82b0a679.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=e2046cfbebe9c9c48d63ffc71bf42ee5',
#      'credits': 'Boris Stroujko',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/4460a840299f4732b0ae64608441163f.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=f4eac8a8116ab9f7cc6752fe66d15a54',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/4460a840299f4732b0ae64608441163f.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=3ef14286f34f68f188067910f57b83b2',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/4460a840299f4732b0ae64608441163f.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=268100a7f058ed58c4d5f661c069ed22',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/4460a840299f4732b0ae64608441163f.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=5eecd297bd34f783d0cfb4c4979db1c9',
#      'credits': 'Rüdiger Wölk',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/71cde7703c9d436b9e3cc311f9eb75da.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=4d8cddb957fba125dcf6ea543ca7d633',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/71cde7703c9d436b9e3cc311f9eb75da.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=3bc8d1dec3735f8c2fde6628cd8fe5d7',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/71cde7703c9d436b9e3cc311f9eb75da.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=230f85bb8744d7bafb50372376c78f0c',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/71cde7703c9d436b9e3cc311f9eb75da.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=bf65a4346e31945965838f52b4b6f17e',
#      'credits': 'Gérard Janot',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/ccea1ad5ad0f4a2cb6493d8056aa9809.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=3ebe074054310ddfe7279ec715f72a89',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/ccea1ad5ad0f4a2cb6493d8056aa9809.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=d1d5e341f92a16bdb26f033adbcfafb7',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/ccea1ad5ad0f4a2cb6493d8056aa9809.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=8c10b357f436a318318359dcf1ef6c07',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/ccea1ad5ad0f4a2cb6493d8056aa9809.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=fa5f2a38f4ca453b0b5199988ccd54bd',
#      'credits': 'Dudva',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/eeac0a5ad890430b969c2860f727cb22.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=320bc9129309fb6965810a687fe3dd67',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/eeac0a5ad890430b969c2860f727cb22.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=725f28a27c7e84c8b557ed07544f7c2c',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/eeac0a5ad890430b969c2860f727cb22.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=673b9825422dee8c8f5cd324e47c095a',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/eeac0a5ad890430b969c2860f727cb22.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=18e78cb12f6896b478e2f897bcd157c9',
#      'credits': 'José Luiz',
#      'alt_text': None}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-the-duomo-di-milano-rooftop-museum-p974232/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-the-duomo-di-milano-rooftop-museum-p974232/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': "Explore Italy's grandest Gothic cathedral with Milan Duomo tickets",
#    'promo_label': 'bestseller',
#    'geolocation': {'lat': 45.4637, 'lng': 9.192},
#    'distance': 0,
#    'venue': {'id': '145637',
#     'name': 'Milan Cathedral – The Duomo',
#     'postal_code': '20122',
#     'address': 'Piazza del Duomo 14/A'},
#    'ratings': {'total': 7705, 'average': 4.7},
#    'currency': 'EUR',
#    'price': 26.0,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 26.0,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-the-duomo-di-milano-rooftop-museum-p974232',
#    'languages': ['es',
#     'ca',
#     'cs',
#     'da',
#     'de',
#     'el',
#     'fr',
#     'it',
#     'ja',
#     'ko',
#     'nl',
#     'pt',
#     'ru',
#     'sv',
#     'zh',
#     'en',
#     'pl'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': 'The Duomo di Milano took almost six centuries to complete – luckily it only takes an hour or so to explore. These tickets give you skip-the-line access to the Milan Duomo, as well as its museum. You can even head to the Duomo rooftop and look out over Milan –\xa0on a clear day, you can even see the Alps.',
#    'whats_included': '* Skip-the-line entrance to the Duomo di Milano\r\n* Skip-the-line entrance to Duomo Museum\r\n* Entrance to Church of San Gottardo (excluded on Wednesday)\r\n* Entrance to the Duomo Rooftops\r\n* Duomo Rooftops by lift or by stairs (choose your favorite option)',
#    'whats_excluded': None,
#    'display_price': 26.0,
#    'display_booking_fee': None,
#    'best_time_to_visit': None,
#    'live_guide_languages': None,
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': None,
#    'starting_point': {'city_id': 71749,
#     'lat': 45.4637,
#     'lng': 9.192,
#     'address': 'Piazza del Duomo 14/A',
#     'label': None},
#    'wheelchair_access': True,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': None,
#    'last_admission_window': None,
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': [1082752, 1013948, 1103227],
#    'package_products': None,
#    'supplier': {'name': 'Veneranda Fabbrica del Duomo',
#     'address': 'Carlo maria Martini 1',
#     'city': 'Milano',
#     'postalcode': '20122',
#     'countrycode': 'IT'},
#    'marketing_restrictions': None,
#    'cancellation': {'policy': 'before_date', 'window': 0}},
#   {'id': '977806',
#    'language': 'en',
#    'title': 'Duomo di Milano: Rooftop Entry Ticket',
#    'city_id': '71749',
#    'country_id': '50109',
#    'tag_ids': ['1234', '1198', '30', '444', '1185', '1235', '1189', '1363'],
#    'images': [{'small': 'https://aws-tiqets-cdn.imgix.net/images/content/90412f5fc5a14372b5f0e8fa85ff0f0c.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=cdb1931d699509eb516837e193c3329d',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/90412f5fc5a14372b5f0e8fa85ff0f0c.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=734b54559e0075242f109d29f4e6327d',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/90412f5fc5a14372b5f0e8fa85ff0f0c.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=c8826a1f1345fdf2a611da3f95bfb00e',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/90412f5fc5a14372b5f0e8fa85ff0f0c.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=8ce3a9ebadcad20f4e45f1a304aea6ef',
#      'credits': 'Daniel Case',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/23a8097a1cea427eb04e068f1653ca7e.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=ee93525ea5d5b5d53d2ab8d7f595335b',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/23a8097a1cea427eb04e068f1653ca7e.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=e2db101e81ad84bac655b53ef58f5a81',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/23a8097a1cea427eb04e068f1653ca7e.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=79a6d88a156cbebaa46d4c6ba58896fa',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/23a8097a1cea427eb04e068f1653ca7e.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=abc01d265e633d827ced89f636e675b1',
#      'credits': '',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/f73f83839c7049778c149621f68a8db6.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=ace1a4f2ad0b5a7747f1ccf077cf1493',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/f73f83839c7049778c149621f68a8db6.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=5434b807fe3be70d9963af8dc19e2a01',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/f73f83839c7049778c149621f68a8db6.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=a130d980a98d289d2f1971737d489781',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/f73f83839c7049778c149621f68a8db6.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s
#     'ca',
#     'ja',
#     'da',
#     'cs',
#     'pl',
#     'pt',
#     'es',
#     'de',
#     'nl',
#     'zh',
#     'it',
#     'ru',
#     'el',
#     'ko',
#     'sv'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': 'This special ticket gets you access to the Duomo rooftop, via the stairs or the elevator, depending on your ticket choice. Enjoy jaw-dropping views of Milan from the terraces and learn the history of the building from a whole new perspective.',
#    'whats_included': '* Entrance to the Duomo Rooftops\r\n* Duomo Rooftops by lift or by stairs (choose your favorite option)',
#    'whats_excluded': '* Admission to the Duomo di Milano, Archaeological Area, Duomo Museum & the Church of San Gottardo\r\n* Guided tour or audio guide',
#    'display_price': 19.0,
#    'display_booking_fee': None,
#    'best_time_to_visit': ['daytime'],
#    'live_guide_languages': None,
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': None,
#    'starting_point': {'city_id': 71749,
#     'lat': 45.4637,
#     'lng': 9.192,
#     'address': 'Piazza del Duomo 14/A',
#     'label': None},
#    'wheelchair_access': True,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': None,
#    'last_admission_window': '1:00:00',
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': None,
#    'package_products': None,
#    'supplier': {'name': 'Veneranda Fabbrica del Duomo',
#     'address': 'Carlo maria Martini 1',
#     'city': 'Milano',
#     'postalcode': '20122',
#     'countrycode': 'IT'},
#    'marketing_restrictions': None,
#    'cancellation': {'policy': 'before_date', 'window': 0}},
#   {'id': '1023884',
#    'language': 'en',
#    'title': 'Duomo di Milano & Museum: Entry Ticket',
#    'city_id': '71749',
#    'country_id': '50109',
#    'tag_ids': ['1234', '1367', '440', '1192', '1198', '1185', '1235', '1363'],
#    'images': [{'small': 'https://aws-tiqets-cdn.imgix.net/images/content/076fe78ead92400f9f4a6a10b5b2f73e.jpeg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=633c992d3675dd2c9225dfe992a517c6',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/076fe78ead92400f9f4a6a10b5b2f73e.jpeg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=d053546bba09591179785e3bd06be6f0',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/076fe78ead92400f9f4a6a10b5b2f73e.jpeg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=1f4b44faf79ca00b3d3f0bda2e5d6fa6',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/076fe78ead92400f9f4a6a10b5b2f73e.jpeg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=5e1dd78910c8d7763ee5f8fd6b4f8946',
#      'credits': 'from product 974232',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/e6303e07a1ae4cedb7d2e2769951d8a2.jpeg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=748b9c2189d4f9698935fde12004653f',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/e6303e07a1ae4cedb7d2e2769951d8a2.jpeg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=e9ab7776744c19eacdd63278185f5882',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/e6303e07a1ae4cedb7d2e2769951d8a2.jpeg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=e984a18b104af5d01312533a0804f8f7',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/e6303e07a1ae4cedb7d2e2769951d8a2.jpeg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=4657e116ce6e282abdf593ee366436f5',
#      'credits': 'from product 991570',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/83407f6b5104400bb5b0bd18e47958cb.jpeg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=cd8f7b87c585cf6339757d22c32399b9',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/83407f6b5104400bb5b0bd18e47958cb.jpeg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=2f1e14c89968e37a5b23884260b28ec7',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/83407f6b5104400bb5b0bd18e47958cb.jpeg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=d6374d7a240755c3b1183071cdef5054',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/83407f6b5104400bb5b0bd18e47958cb.jpeg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=68eb77b441de251c378aa8120862fcea',
#      'credits': 'from product  1001243',
#      'alt_text': None}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-the-duomo-di-milano-and-duomo-museum-p1023884/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-the-duomo-di-milano-and-duomo-museum-p1023884/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': 'Explore inside the iconic Milan Cathedral and get access to the museum',
#    'promo_label': 'bestseller',
#    'geolocation': {'lat': 45.4637, 'lng': 9.192},
#    'distance': 0,
#    'venue': {'id': '145637',
#     'name': 'Milan Cathedral – The Duomo',
#     'postal_code': '20122',
#     'address': 'Piazza del Duomo 14/A'},
#    'ratings': {'total': 1231, 'average': 4.5},
#    'currency': 'EUR',
#    'price': 11.5,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 11.5,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-the-duomo-di-milano-and-duomo-museum-p1023884',
#    'languages': ['it',
#     'nl',
#     'ca',
#     'zh',
#     'fr',
#     'en',
#     'cs',
#     'da',
#     'ja',
#     'pt',
#     'sv',
#     'es',
#     'pl',
#     'el',
#     'ko',
#     'de',
#     'ru'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': "The Milan Cathedral, or Duomo di Milano if you want to say it like the locals, is one fabulous addition to your Milan itinerary. These tickets get you inside the Duomo to explore the intricacies of the largest Gothic Cathedral in Europe.\r\n\r\nSoak up the treasures and artistic touches inside the imposing church. Admire the incredible naves, and the way the light glimmers through the stained-glass windows. Study the sarcophagi, and get up close to the finely decorated altars. If you are lucky, you may even get a peak at the Holy Nail, a relic from the crucifix of Jesus Christ. \r\n\r\nDelve into the Duomo's past in the museum and see a mini replica of it, then visit the Church of San Gottardo in Corte, built by the Lord of Milan in the 14th century. The church and its soaring bell tower is the perfect palate cleanser after your day of cultural exploration. (Please note: the museum and Church of San Gottardo are closed on Wednesday).",
#    'whats_included': '* Entrance to the Duomo di Milano (only cathedral)\r\n* Entrance to Duomo Museum\r\n* Entrance to Church of San Gottardo (excluded on Wednesday)',
#    'whats_excluded': '* Entrance to the Milan Cathedral Terraces\r\n* Entrance to the Archaeological Park\r\n* Audio guide',
#    'display_price': 11.5,
#    'display_booking_fee': None,
#    'best_time_to_visit': None,
#    'live_guide_languages': None,
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': None,
#    'starting_point': {'city_id': 71749,
#     'lat': 45.4637,
#     'lng': 9.192,
#     'address': 'Piazza del Duomo 14/A',
#     'label': None},
#    'wheelchair_access': False,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': None,

#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/fb84a811ef374ae19d7090ae45841dbe.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=0a6bba28d9df2174ea2692f2810a4b97',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/fb84a811ef374ae19d7090ae45841dbe.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=7f9df761de46c9edf052333a2de59815',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/fb84a811ef374ae19d7090ae45841dbe.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=909712cb2e7117add5294e50ddd036d7',
#      'credits': 'Museo Scienza',
#      'alt_text': 'Aeronaval Pavilion'},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/0fb93be747fe430eac3a941f8ca8bb18.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=062870b8752f3a5679625e659443e8f0',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/0fb93be747fe430eac3a941f8ca8bb18.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=097efd360cfc1a5bf0b278368eda5f04',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/0fb93be747fe430eac3a941f8ca8bb18.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=b31aaa5876b459775387931c333adf52',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/0fb93be747fe430eac3a941f8ca8bb18.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=5ab967c2abc74045bfaa0dcff96aa570',
#      'credits': 'Museo Scienza',
#      'alt_text': 'Leonardo da Vinci Galleries'},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/8d9652125f1a47b7b048755500157c31.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=2d3c893c072498134b62907c92bff598',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/8d9652125f1a47b7b048755500157c31.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=865f450e8388858a6918e94969a73f24',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/8d9652125f1a47b7b048755500157c31.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=846ed12ac8b28bf55cf02c067e861418',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/8d9652125f1a47b7b048755500157c31.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=86973537498f917881fcf01a6a07b7a4',
#      'credits': 'Museo Scienza',
#      'alt_text': 'i.Lab Leonardo'},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/4f79629563c04a63a6b68e83361cece6.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=1fdc08b9f5bff76d838e49fd73ebd2a3',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/4f79629563c04a63a6b68e83361cece6.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=e3d539e2799a31300bdaf7c13e707a73',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/4f79629563c04a63a6b68e83361cece6.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=b7415806024f94aacd206b7c52827229',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/4f79629563c04a63a6b68e83361cece6.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=5685373ea93731c7ee53a2afc505cf62',
#      'credits': 'Museo Scienza',
#      'alt_text': 'Leonardo da Vinci Galleries'}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-museum-science-and-technology-leonardo-da-vinci-fast-track-p974236/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-museum-science-and-technology-leonardo-da-vinci-fast-track-p974236/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': 'The largest science museum in Italy',
#    'promo_label': 'bestseller',
#    'geolocation': {'lat': 45.461506, 'lng': 9.170926},
#    'distance': 1,
#    'venue': {'id': '145640',
#     'name': 'National Museum Science and Technology Leonardo da Vinci',
#     'postal_code': '20123',
#     'address': '21,Via San Vittore'},
#    'ratings': {'total': 1109, 'average': 4.6},
#    'currency': 'EUR',
#    'price': 10.0,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 10.0,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-museum-science-and-technology-leonardo-da-vinci-fast-track-p974236',
#    'languages': ['ca',
#     'cs',
#     'da',
#     'de',
#     'es',
#     'pl',
#     'sv',
#     'fr',
#     'it',
#     'pt',
#     'zh',
#     'ja',
#     'ko',
#     'en',
#     'el',
#     'nl',
#     'ru'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': "Milan's Leonardo da Vinci Museum of Science and Technology ('Museo Nazionale Scienza e Tecnologia Leonardo da Vinci') is housed in a 16th-century monastery and features a collection of **more than 16,000 items** – including models based on da Vinci's engineering sketches. \r\n\r\nIt's a fascinating place to delve into the mind of genius overachiever da Vinci, and learn about cutting-edge tech.",
#    'whats_included': "* Access to Milan's Leonardo Da Vinci Museum of Science and Technology\r\n* Access to the temporary exhibition (depending on availability)",
#    'whats_excluded': None,
#    'display_price': 10.0,
#    'display_booking_fee': None,
#    'best_time_to_visit': None,
#    'live_guide_languages': None,
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': None,
#    'starting_point': {'city_id': 71749,
#     'lat': 45.461506,
#     'lng': 9.170926,
#     'address': '21,Via San Vittore',
#     'label': None},
#    'wheelchair_access': True,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': '0:05:00',
#    'last_admission_window': None,
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': [1013948],
#    'package_products': None,
#    'supplier': {'name': 'National Museum Science and Technology Leonardo da Vinci',
#     'address': 'via San Vittore, 21',
#     'city': 'Milan',
#     'postalcode': '20123',
#     'countrycode': 'IT'},
#    'marketing_restrictions': None,
#    'cancellation': {'policy': 'before_date', 'window': 0}},
#   {'id': '991570',
#    'language': 'en',
#    'title': 'Duomo di Milano, Museum & Archaeological Area: Entry Ticket',
#    'city_id': '71749',
#    'country_id': '50109',
#    'tag_ids': ['30',
#     '440',
#     '1234',
#     '1192',
#     '1194',
#     '1198',
#     '1185',
#     '1235',
#     '1188',
#     '1368',
#     '1367',
#     '1363'],
#    'images': [{'small': 'https://aws-tiqets-cdn.imgix.net/images/content/ba68144e8a5a44d2994389eb8fafe632.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=f27816a476e185fbd2b88fe019023f63',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/ba68144e8a5a44d2994389eb8fafe632.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=c22995360c4431447aea5f895bb9632a',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/ba68144e8a5a44d2994389eb8fafe632.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=91fcdc37610ba5c75bbf6d3029f692ea',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/ba68144e8a5a44d2994389eb8fafe632.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=3f0d368b0855f43fafb94b207ed1da34',
#      'credits': 'Noppasin Wongchum',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/73c53a7bae3d4d5aa423ad9433f44794.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=84072f0eb78542a384016c5f183a0526',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/73c53a7bae3d4d5aa423ad9433f44794.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=9c1ea8492f263525a4d9f15efbd48132',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/73c53a7bae3d4d5aa423ad9433f44794.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=682f77e662a36b798fcab0324103fec6',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/73c53a7bae3d4d5aa423ad9433f44794.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=7938713098db3536314c658ce32541fd',
#      'credits': None,
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/98a8b99c6942461f9879f2ffb1099361.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=36fdefc6e7ba581d04b18bf4f672146a',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/98a8b99c6942461f9879f2ffb1099361.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=d3edd8b7a04cee1357b8f036ae86bdca',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/98a8b99c6942461f9879f2ffb1099361.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=259974618befb374bb325582ff56eb2d',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/98a8b99c6942461f9879f2ffb1099361.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=cb48cb6f6f3c4b1240b5341454659d57',
#      'credits': 'Sa-nguansak Supong',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/f685d3c376b34e81b6b8552b9990f631.png?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=8501804c77a32349f1216c8d84b37ce0',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/f685d3c376b34e81b6b8552b9990f631.png?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=66c1cbc1f4fce505771bacd6bbdc535a',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/f685d3c376b34e81b6b8552b9990f631.png?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=62303342d658ec9845a4f3370d430635',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/f685d3c376b34e81b6b8552b9990f631.png?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=1c8e06ba36ce5f8f3fea443730548ae7',
#      'credits': None,
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/b9925706f8c24450b8dc8cf9c3ce8579.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=dddaf94b47d846df06040941702bb585',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/b9925706f8c24450b8dc8cf9c3ce8579.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=c470df8852a00ded8a4901810f8f6de9',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/b9925706f8c24450b8dc8cf9c3ce8579.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=caa5a2affa1244d5a4dce1451543a4a6',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/b9925706f8c24450b8dc8cf9c3ce8579.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=da65e2b390f139516556dfe6c46fcd50',
#      'credits': 'Boris Stroujko',
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/57031dedf586403eb8a6ec6f80675ba6.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=ef1e55983a90327fd6334376df07970b',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/57031dedf586403eb8a6ec6f80675ba6.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=6df1e9aabc7c6beac2c5d93b33000c2f',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/57031dedf586403eb8a6ec6f80675ba6.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=3d1c3e27b71b2ceaf034b98ae620a101',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/57031dedf586403eb8a6ec6f80675ba6.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=7c81f70320e0e37acb9bb3e8f418ba82',
#      'credits': None,
#      'alt_text': None}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-the-duomo-di-milano-museum-archaeological-area-p991570/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-the-duomo-di-milano-museum-archaeological-area-p991570/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': "See Milan's masterpiece of Gothic architecture, its museum, and go underground",
#    'promo_label': None,
#    'geolocation': {'lat': 45.4637, 'lng': 9.192},
#    'distance': 0,
#    'venue': {'id': '145637',
#     'name': 'Milan Cathedral – The Duomo',
#     'postal_code': '20122',
#     'address': 'Piazza del Duomo 14/A'},
#    'ratings': {'total': 238, 'average': 4.5},
#    'currency': 'EUR',
#    'price': 15.5,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 15.5,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-the-duomo-di-milano-museum-archaeological-area-p991570',
#    'languages': ['es',
#     'fr',
#     'nl',
#     'zh',
#     'da',
#     'de',
#     'el',
#     'it',
#     'ja',
#     'pt',
#     'ru',
#     'sv',
#     'en',
#     'ko',
#     'pl',
#     'ca',
#     'cs'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': "Gothic architecture doesn't get much more dramatic or spectacular than the Duomo di Milano. A towering edifice of spiky spires, gloomy gargoyles, and captivating Christian art, it's the must-see cultural attraction in Milan. Explore this Milanese masterpiece with these The Duomo di Milano tickets, which include a self-guided tour of the Duomo Cathedral, Duomo Museum, the subterranean archaeological area, and enter the Church of San Gottardo in Corte.",
#    'whats_included': '* Entrance to the Duomo di Milano (only cathedral)\r\n* Entrance to Duomo Museum\r\n* Entrance to Church of San Gottardo (excluded on Wednesday)\r\n* Entrance to Archaeological Area',
#    'whats_excluded': '* Access to the Duomo Rooftops',
#    'display_price': 15.5,
#    'display_booking_fee': None,
#    'best_time_to_visit': ['daytime'],
#    'live_guide_languages': None,
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': None,
#    'starting_point': {'city_id': 71749,
#     'lat': 45.4637,
#     'lng': 9.192,
#     'address': 'Piazza del Duomo 14/A',
#     'label': None},
#    'wheelchair_access': True,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': None,
#    'last_admission_window': '1:00:00',
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': None,
#    'package_products': None,
#    'supplier': {'name': 'Veneranda Fabbrica del Duomo',
#     'address': 'Carlo maria Martini 1',
#     'city': 'Milano',
#     'postalcode': '20122',
#     'countrycode': 'IT'},
#    'marketing_restrictions': None,
#    'cancellation': {'policy': 'before_date', 'window': 0}},
#   {'id': '974230',
#    'language': 'en',
#    'title': 'Casa Milan Museum: Entry Ticket',
#    'city_id': '71749',
#    'country_id': '50109',
#    'tag_ids': ['1944', '1363', '442', '1201', '1186', '1187', '1189'],
#    'images': [{'small': 'https://aws-tiqets-cdn.imgix.net/images/content/78bdaf14067f4022bae1aebad230c00e.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=a9a9b012a0694d8070a62b9b5c73acd7',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/78bdaf14067f4022bae1aebad230c00e.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=8e0b936b3ed7d06597df6ed1de5213b5',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/78bdaf14067f4022bae1aebad230c00e.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=270daac09ed03e5cf26031d41aa73430',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/78bdaf14067f4022bae1aebad230c00e.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=a28f04aede9041ff39d01fbd7fd3105d',
#      'credits': None,
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/bf2da32a73534a8cb9c57026e4a031dc.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=a724f8f10ddc77b204ca6cefe5f7535e',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/bf2da32a73534a8cb9c57026e4a031dc.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=8f868d1e2807509988350d39ce6e1f1f',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/bf2da32a73534a8cb9c57026e4a031dc.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=04d361c0ebbfb9e3d4a5b4fd7950ce9b',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/bf2da32a73534a8cb9c57026e4a031dc.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=86697f0479a7551d1747b556d467fe32',
#      'credits': None,
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/90b62b7c4c0749c59ccb1c5a6dcf82d6.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=ab6b72466bdf10e630dc044c9b7b1c60',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/90b62b7c4c0749c59ccb1c5a6dcf82d6.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=ec633ef3408a370a083a567173c7a74a',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/90b62b7c4c0749c59ccb1c5a6dcf82d6.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=a8708e01282228bc036fef4816887c9c',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/90b62b7c4c0749c59ccb1c5a6dcf82d6.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=c5bd5b60a78ea34024db5ebfc549c770',
#      'credits': None,
#      'alt_text': None},
#     {'small': 'https://aws-tiqets-cdn.imgix.net/images/content/db7e0665762c4f6590f19d21b77ea49c.jpg?auto=format%2Ccompress&fit=crop&h=128&ixlib=python-3.2.1&q=70&w=128&s=cf179402c9dac96316009af3d74b4e66',
#      'medium': 'https://aws-tiqets-cdn.imgix.net/images/content/db7e0665762c4f6590f19d21b77ea49c.jpg?auto=format%2Ccompress&fit=crop&h=250&ixlib=python-3.2.1&q=70&w=250&s=31aef80da724def48fe7d9e0cee22eb2',
#      'large': 'https://aws-tiqets-cdn.imgix.net/images/content/db7e0665762c4f6590f19d21b77ea49c.jpg?auto=format%2Ccompress&fit=crop&h=500&ixlib=python-3.2.1&q=70&w=500&s=254cf18f32c0e382460b346ceac49604',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/db7e0665762c4f6590f19d21b77ea49c.jpg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s
jpeg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=e436fff4aa08f40f151388de636000d3',
#      'credits': 'Ways Tours srl',
#      'alt_text': 'Milan Ebike Tour - Duomo Cathedral'}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-milan-grand-city-highlights-e-bike-tour-p1049349/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-milan-grand-city-highlights-e-bike-tour-p1049349/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': 'Meet a local insider and discover Milan on a fun and pleasant E-bike tour!',
#    'promo_label': 'out_of_season',
#    'geolocation': {'lat': 45.484225, 'lng': 9.209928},
#    'distance': 3,
#    'venue': {'id': '205440',
#     'name': 'Milan City Tours',
#     'postal_code': None,
#     'address': None},
#    'ratings': {'total': 1, 'average': 4.0},
#    'currency': 'EUR',
#    'price': 45.0,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 45.0,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-milan-grand-city-highlights-e-bike-tour-p1049349',
#    'languages': ['el',
#     'es',
#     'fr',
#     'ko',
#     'pl',
#     'ru',
#     'zh',
#     'ja',
#     'nl',
#     'pt',
#     'it',
#     'ca',
#     'de',
#     'en',
#     'da',
#     'cs',
#     'sv'],
#    'sale_status': 'unavailable',
#    'sale_status_reason': 'The product is out of season.',
#    'sale_status_expected_reopen': '2025-01-31',
#    'summary': "Uncover the thrilling fusion of innovation and tradition in Milan with a guided E-bike tour of the world's fashion capital. On this leisurely urban exploration, you'll have the opportunity to witness the trendy fashion and design made in Italy, as well as the renowned historical monuments this iconic city is renowned for.\r\n\r\nKicking off at Navigli, one of the most beloved spots among Milan's natives that's renowned for the classic Aperitivo ritual. You'll pedal through the city, discovering the majestic San Lorenzo Columns – an iconic Roman archaeological site – and learn about the ancient history of the city.\r\n\r\nCruise down the renowned streets, admiring the majestic Duomo, the Sforzesco Palace, the Sempione Park and the elegant Vittorio Emanuele Gallery. As you journey through the city, get a glimpse into the modern districts, including Piazza Gae Aulenti, with its stunning Vertical Wood building. This tour will offer a totally new perspective of the city!",
#    'whats_included': '* E-Bikes\r\n* Helmets\r\n* Raincoat (if needed)',
#    'whats_excluded': '* Audioguide',
#    'display_price': 45.0,
#    'display_booking_fee': None,
#    'best_time_to_visit': ['morning', 'daytime'],
#    'live_guide_languages': ['en'],
#    'audio_guide_languages': None,
#    'starting_time': None,
#    'timezone': 'Europe/Rome',
#    'duration': '03:30',
#    'starting_point': {'city_id': 71749,
#     'lat': 45.484225,
#     'lng': 9.209928,
#     'address': 'Milan, Waystours, Via Franchino Gaffurio, 3',
#     'label': 'Via Francesco Londonio, 17, Milano, Metropolitan City of Milan, Italy'},
#    'wheelchair_access': False,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': '0:10:00',
#    'last_admission_window': None,
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': None,
#    'package_products': None,
#    'supplier': {'name': 'Ways srl',
#     'address': 'Vicolo Carmelitani Scalzi 14B',
#     'city': 'Verona',
#      'extra_large': 'https://aws-tiqets-cdn.imgix.net/images/content/b12ab5b3b3874ae9b7d2af620f308051.jpeg?auto=format%2Ccompress&fit=crop&h=1284&ixlib=python-3.2.1&q=70&w=1284&s=9098abf8f232e8c908af20ee03e81d96',
#      'credits': 'VEDITALIA',
#      'alt_text': 'The Sforza Castle'}],
#    'product_url': 'https://www.tiqets.com/en/milan-attractions-c71749/tickets-for-duomo-of-milan-last-supper-skip-the-line-guided-walking-tour-p1093832/',
#    'product_checkout_url': 'https://www.tiqets.com/en/checkout/tickets-for-duomo-of-milan-last-supper-skip-the-line-guided-walking-tour-p1093832/booking_details/',
#    'is_package': False,
#    'country_name': 'Italy',
#    'city_name': 'Milan',
#    'tagline': "Witness Milan's iconic landmarks and Leonardo da Vinci's renowned masterpiece",
#    'promo_label': None,
#    'geolocation': {'lat': 45.4686088, 'lng': 9.1760713},
#    'distance': 1,
#    'venue': {'id': '205440',
#     'name': 'Milan City Tours',
#     'postal_code': None,
#     'address': None},
#    'ratings': {'total': 1, 'average': 1.0},
#    'currency': 'EUR',
#    'price': 135.0,
#    'prediscount_price': None,
#    'price_in_supplier_currency': 135.0,
#    'supplier_currency': 'EUR',
#    'product_slug': 'tickets-for-duomo-of-milan-last-supper-skip-the-line-guided-walking-tour-p1093832',
#    'languages': ['ca',
#     'de',
#     'ja',
#     'cs',
#     'da',
#     'el',
#     'es',
#     'fr',
#     'it',
#     'ko',
#     'nl',
#     'pl',
#     'pt',
#     'ru',
#     'sv',
#     'zh',
#     'en'],
#    'sale_status': 'available',
#    'sale_status_reason': '',
#    'sale_status_expected_reopen': None,
#    'summary': 'Explore Milan on a full-day tour with an experienced English-speaking guide. Visit iconic landmarks like Sforza Castle, the Duomo Cathedral, and hidden gems such as San Maurizio al Monastero Maggiore.\r\n\r\nDiscover contemporary art like Maurizio Cattelan\'s "The Finger" and stroll through the Vittorio Emanuele II Gallery. Witness the magic of La Scala Opera Theatre and admire Leonardo da Vinci\'s Last Supper.\r\n\r\nTake a leisurely 60 to 90-minute break for coffee and lunch. This Milan adventure promises a day of discovery with a knowledgeable guide.',
#    'whats_included': '* Skip-the-line ticket to Milan Cathedral\r\n* Skip-the-line ticket to The Last Supper\r\n* Entry to the Church of San Maurizio al Monastero Maggiore\r\n* Professional English-speaking tour guide\r\n* Headsets for over 5 participants',
#    'whats_excluded': '* Food and drinks',
#    'display_price': 135.0,
#    'display_booking_fee': None,
#    'best_time_to_visit': None,
#    'live_guide_languages': ['en'],
#    'audio_guide_languages': ['en'],
#    'starting_time': '09:30:00',
#    'timezone': 'Europe/Rome',
#    'duration': '06:00',
#    'starting_point': {'city_id': 71749,
#     'lat': 45.4686088,
#     'lng': 9.1760713,
#     'address': '10 Piazzale Luigi Cadorna',
#     'label': None},
#    'wheelchair_access': False,
#    'skip_line': None,
#    'smartphone_ticket': True,
#    'advance_arrival_time': '0:15:00',
#    'last_admission_window': '2:55:00',
#    'description': None,
#    'highlights': None,
#    'safety_measures': None,
#    'exhibitions': None,
#    'reviews': None,
#    'instant_ticket_delivery': True,
#    'discount_percentage': 0.0,
#    'promotion_highlight': None,
#    'in_packages': None,
#    'package_products': None,
#    'supplier': {'name': 'Vedi Italia - Acs srl',
#     'address': 'via Villoresi 4',
#     'city': 'Milano',
#     'postalcode': '20143',
#     'countrycode': 'IT'},
#    'marketing_restrictions': None,
#    'cancellation': {'policy': 'before_timeslot', 'window': 24}}],
#  'pagination': {'page': 1, 'page_size': 100, 'total': 122}}

# %%
def group_products_by_venue(products):
    """
    Group products by venue and return a dictionary with the grouped products.
    Each venue will have a list of products associated with it.
    """
    grouped_products = {}

    for product in products:
        # Extract venue info
        venue = product.get('venue', {})
        venue_name = venue.get('name', "Unknown Venue")
        address = venue.get('address', "Unknown Address")
        city_name = product.get('city_name', "Unknown City")
        lat, lng = product['geolocation'].get('lat'), product['geolocation'].get('lng')

        # Group by venue name, initializing the venue entry if necessary
        venue_info = grouped_products.setdefault(venue_name, {
            'name': venue_name,
            'address': address,
            'products': [],
            'city': city_name,
            'lat': lat,
            'lng': lng
        })

        venue_info['products'].append(product)

    return grouped_products

# %%
def match_score(venue, place):
    """
    Calculate a match score between a product and a place based on their names.
    The score is calculated as the number of common words between the two names.
    """

    name_score = fuzz.token_sort_ratio(place['displayName']['text'].lower(), venue['name'].lower()) / 100

    # Compare addresses (you could use a more sophisticated method for address normalization)
    venue_address1 = f"{venue['address']}, {venue['city']}"
    venue_address2 = f"{venue['name']}, {venue['address']}, {venue['city']}"

    address_score1 = fuzz.token_sort_ratio(venue_address1, place['shortFormattedAddress'])
    address_score2 = fuzz.token_sort_ratio(venue_address2, place['shortFormattedAddress'])

    address_score = max(address_score1, address_score2) / 100

    # Compare coordinates (geodesic distance)
    venue_coords = (venue['lat'], venue['lng'])
    place_coords = (place['location']['latitude'], place['location']['longitude'])

    distance = geodesic(venue_coords, place_coords).meters

    coord_score = max(0, 1 - (distance / 1000))  # Normalize to a max distance of 1 km

    # Calculate total score (weight based on importance)
    total_score = (name_score * 0.4) + (address_score * 0.4) + (coord_score * 0.2)

    return total_score

# %%
def tiqets_products(lat, lng, radius):
    """
    Fetch products from Tiqets API and return them as JSON.
    Example URL: /tiqets-products/?lat=52.3676&lng=4.9041&radius=5000
    """

    if lat is None or lng is None:
        return JsonResponse({'error': 'Latitude and Longitude are required.'}, status=400)

    # Convert lat, lng, and radius to the correct types
    try:
        lat = float(lat)
        lng = float(lng)
        radius = int(radius)
    except ValueError:
        return JsonResponse({'error': 'Invalid latitude, longitude, or radius values.'}, status=400)

    # Fetch data from Tiqets API using the utility function
    products_data = get_tiqets_products(lat, lng, radius)

    return JsonResponse(products_data)

# %%
def get_average_price_from_tiqets(venue_products):
    total = 0
    count = 0
    for product in venue_products:
        if product.get('price'):
            count += 1
            total += product.get('price')

    if count> 0:
        return total/count

def get_minimum_price_from_tiqets(venue_products):
    min = 99999999
    tiqet_id = None
    for product in venue_products:
        if product.get('price') and product.get('price')<min:
            min = product.get('price')
            tiqet_id = product.get('id')

    return min, tiqet_id

# %%
def get_average_rating_from_tiqets(venue_products):
    total = 0
    count = 0
    for product in venue_products:
        if product.get('ratings'):
            count += 1
            total += product.get('ratings').get('average')

    if count> 0:
        return total/count

    return 0

def get_amount_of_rating_from_tiqets(venue_products):
    total = 0

    for product in venue_products:
        if product.get('ratings'):
            total += product.get('ratings').get('total')

    return total

def order_tiqets_by_price(venue_products):
    sorted_products = sorted(
        venue_products,
        key=lambda product: product.get('price', float('inf'))  # Use 'inf' if price is missing
    )

    sorted_id_price_pairs = [(product.get('id'), product.get('price')) for product in sorted_products]

    return sorted_id_price_pairs

# %%
import re
from collections import Counter
from string import punctuation

def extract_keywords(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove punctuation
    text = re.sub(f"[{re.escape(punctuation)}]", "", text)

    # Tokenize the words (split by whitespace)
    words = text.split()

    # Remove common stop words
    stopwords = {"the", "a", "an", "and", "or", "to", "as", "you", "your", "of", "its", "it", "in", "is", "for", "on"}
    filtered_words = [word for word in words if word not in stopwords]


    # Return unique keywords
    return list(filtered_words)

# %%
from collections import Counter

def get_descriptions(products):
    all_keywords = []

    for prod in products:
        if prod.get('tagline'):
            desc = prod.get('tagline')

            # Extract keywords from the tagline
            keywords = extract_keywords(desc)
            all_keywords.extend(keywords)
            
    # Return as a list of tuples (word, count)
    return list(all_keywords)

# %%
def get_place_opening_hours(place):
  """
  Returns the opening hours of a place.
  If the place is open 24/7, it creates the data structure to represent that. By Google conventions, a place open 24/7 will
    have only the opening time of the first day of the week at midnight, with no closing time.
  Returns None if the opening hours are not avaiable.
  """

  opening_hours = None

  if place:
    if place.get('regularOpeningHours'):
      if place.get('regularOpeningHours').get('periods'):
        opening_hours = place.get('regularOpeningHours').get('periods')

        # if open 24/7
        if opening_hours[0].get('close') is None:
          opening_hours[0]['close'] = {
              'day': 0,
              'hour': 23,
              'minute': 59
            }
          for i in range(1, 7):
            opening_hours.append({
                'open': {
                  'day': i,
                  'hour': 0,
                  'minute': 0
                },
                'close': {
                  'day': i,
                  'hour': 23,
                  'minute': 59
                }
              }
            )

  return opening_hours

# %%
def merge_tiqets_and_places(lat, lng, radius):
    """
    Fetch places from Google Places API and Tiqets API and return them as JSON.
    Example URL: /merge-tiqets-places/?lat=45.4642&lng=9.1900&radius=5
    """

    # Convert lat, lng, and radius to the correct types
    try:
        lat = float(lat)
        lng = float(lng)
        radius = int(radius)
    except ValueError:
        return JsonResponse({'error': 'Invalid latitude, longitude, or radius values.'}, status=400)

    # Fetch data from Google Places API using the utility function
    places_data = get_places(lat, lng, radius).get('places', [])

    # Fetch data from Tiqets API using the utility function
    tiqets_data = get_tiqets_products(lat, lng, radius).get('products', [])

    # Group products by venue
    grouped_products = group_products_by_venue(tiqets_data)

     # Initialize categories
    tiqetsXplaces = []  # Matches between Tiqets and Places
    places_only = []    # Places without a matching Tiqets venue
    tiqets_only = []    # Tiqets venues without a matching Plac

    # placesXtiqets
    for place in places_data:
        for venue_name, venue_info in grouped_products.items():
            score = match_score(venue_info, place)
            average_price = get_average_price_from_tiqets(venue_info.get('products'))
            tiqets_by_price_asc = order_tiqets_by_price(venue_info.get('products'))
            average_rating = get_average_rating_from_tiqets(venue_info.get('products'))
            opening_hours = get_place_opening_hours(place)
            if score > 0.7:

                tiqetsXplaces.append({
                    'place': place['displayName']['text'],
                    'venue': venue_info.get('name'),
                    'id': place.get('id'),
                    'average_price': average_price,
                    'tiqets_by_price': tiqets_by_price_asc,
                    'rating': place.get('rating'),
                    'tiqets_average_rating': average_rating,
                    'categories': place.get('types'),
                    'score': score,
                    'opening_hours': opening_hours
                })

    # places
    for place in places_data:
        if not any(place['displayName']['text'] in item['place'] for item in tiqetsXplaces):
            opening_hours = get_place_opening_hours(place)
            places_only.append({
                'place': place['displayName']['text'],
                'rating': place.get('rating'),
                'categories': place.get('types'),
                'venue': "No matching Venue",
                'average_price': None,
                'opening_hours': opening_hours,
                'score': 0
            })

    # tiqets
    for venue_name, venue_info in grouped_products.items():
        if not any(venue_info.get('name') in item['venue'] for item in tiqetsXplaces):

            descriptions = get_descriptions(venue_info.get('products'))
            average_price = get_average_price_from_tiqets(venue_info.get('products'))
            total_ratings = get_amount_of_rating_from_tiqets(venue_info.get('products'))
            tiqets_by_price_asc = order_tiqets_by_price(venue_info.get('products'))
            average_rating = get_average_rating_from_tiqets(venue_info.get('products'))

            tiqets_only.append({
                'venue': venue_info.get('name'),
                'average_price': average_price,
                'tiqets_by_price': tiqets_by_price_asc,
                'tiqets_average_rating': average_rating,
                'total_ratings': total_ratings,
                'place': "No matching Place",
                'description':  descriptions,
                'score': 0
            })

    merged_data = {"tiqetsXplaces": tiqetsXplaces, "places_only":places_only, "tiqets_only":tiqets_only}
    return merged_data

# %%
lat = 45.461355
lng = 9.186311
radius = 5

response = merge_tiqets_and_places(lat, lng, radius)
print("tiqets x places")
for res in response.get("tiqetsXplaces"):
    print(res)

print("Places only")
for res in response.get("places_only"):
    print(res)

print("Tiqets only")
for res in response.get("tiqets_only"):
    print(res)
# Out:
# tiqets x places
# {'place': 'Duomo di Milano', 'venue': 'Milan Cathedral – The Duomo', 'id': None, 'average_price': 56.1, 'tiqets_by_price': [('1023884', 11.5), ('991570', 15.5), ('977806', 19.0), ('976152', 22.0), ('974232', 26.0), ('976045', 39.0), ('1092629', 45.0), ('1091087', 48.0), ('1091039', 54.0), ('1100689', 59.0), ('1093819', 64.9), ('1088289', 65.0), ('1092636', 65.0), ('1001243', 68.0), ('1099395', 68.0), ('1091679', 69.0), ('1046102', 78.0), ('1001239', 110.0), ('1099713', 139.0)], 'rating': 4.8, 'tiqets_average_rating': 3.689473684210526, 'categories': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 
# {'place': 'Indro Montanelli Gardens', 'rating': 4.4, 'categories': ['park', 'tourist_attraction', 'point_of_interest', 'establishment'], 'venue': 'No matching Venue', 'average_price': None, 'opening_hours': [{'open': {'day': 0, 'hour': 6, 'minute': 30}, 'close': {'day': 0, 'hour': 21, 'minute': 0}}, {'open': {'day': 1, 'hour': 6, 'minute': 30}, 'close': {'day': 1, 'hour': 21, 'minute': 0}}, {'open': {'day': 2, 'hour': 6, 'minute': 30}, 'close': {'day': 2, 'hour': 21, 'minute': 0}}, {'open': {'day': 3, 'hour': 6, 'minute': 30}, 'close': {'day': 3, 'hour': 21, 'minute': 0}}, {'open': {'day': 4, 'hour': 6, 'minute': 30}, 'close': {'day': 4, 'hour': 21, 'minute': 0}}, {'open': {'day': 5, 'hour': 6, 'minute': 30}, 'close': {'day': 5, 'hour': 21, 'minute': 0}}, {'open': {'day': 6, 'hour': 6, 'minute': 30}, 'close': {'day': 6, 'hour': 21, 'minute': 0}}], 'score': 0}
# Tiqets only
# {'venue': 'Casa Milan Museum', 'average_price': 16.5, 'tiqets_by_price': [('974230', 16.5)], 'tiqets_average_rating': 4.7, 'total_ratings': 597, 'place': 'No matching Place', 'description': ['modern', 'hq', 'beloved', 'serie', 'side', 'ac', 'milan'], 'score': 0}
# {'venue': 'Leonardo3 Museum', 'average_price': 19.0, 'tiqets_by_price': [('974303', 19.0)], 'tiqets_average_rating': 4.5, 'total_ratings': 332, 'place': 'No matching Place', 'description': ['genius', 'da', 'vinci', 'comes', 'life'], 'score': 0}
# {'venue': 'Milan City Tours', 'average_price': 76.61428571428571, 'tiqets_by_price': [('1086158', 38.0), ('1094267', 44.0), ('1049349', 45.0), ('1060147', 66.3), ('1092474', 89.0), ('1062030', 119.0), ('1093832', 135.0)], 'tiqets_average_rating': 2.0285714285714285, 'total_ratings': 79, 'place': 'No matching Place', 'description': ['enjoy', 'skiptheline', 'access', 'leonardos', 'masterpiece', 'last', 'supper', 'uncover', 'milans', 'timeless', 'architectural', 'treasures', 'with', 'skiptheline', 'access', 'discover', 'beauty', 'milan', 'under', 'moonlight', 'with', 'guided', 'tour', 'explore', 'milan', 'witness', 'leonardo', 'da', 'vincis', 'last', 'supper', 'discover', 'milans', 'rich', 'history', 'iconic', 'landmarks', 'meet', 'local', 'insider', 'discover', 'milan', 'fun', 'pleasant', 'ebike', 'tour', 'witness', 'milans', 'iconic', 'landmarks', 'leonardo', 'da', 'vincis', 'renowned', 'masterpiece'], 'score': 0}
# {'venue': 'Teatro alla Scala', 'average_price': 40.44, 'tiqets_by_price': [('1045660', 34.2), ('974742', 39.0), ('1046672', 39.0), ('1092709', 43.0), ('1093501', 47.0)], 'tiqets_average_rating': 3.84, 'total_ratings': 399, 'place': 'No matching Place', 'description': ['1hour', 'walking', 'tour', 'one', 'worlds', 'most', 'famous', 'opera', 'houses', 'tour', 'one', 'italys', 'most', 'impressive', 'opera', 'houses', 'from', 'theatre', 'museum', 'la', 'scala', 'has', 'lot', 'offer', 'join', 'this', 'guided', '15hour', 'experience', 'at', 'la', 'scala', 'discover', 'true', 'milan', 'from', 'old', 'new', 'fun', 'cycling', 'tour'], 'score': 0}
# {'venue': 'Milan Hop-On Hop-Off Tours', 'average_price': 22.666666666666668, 'tiqets_by_price': [('1105678', 19.0), ('1066850', 24.0), ('975062', 25.0)], 'tiqets_average_rating': 2.766666666666667, 'total_ratings': 242, 'place': 'No matching Place', 'description': ['pass', 'best', 'bits', 'milan', 'plus', 'free', 'onboard', 'wifi', 'audio', 'guide', 'discover', 'milan', 'city', 'known', 'style', 'visit', 'sforza', 'castle', 'pass', 'through', 'teatro', 'alla', 'scala'], 'score': 0}
# {'venue': 'Santa Maria delle Grazie', 'average_price': 99.0, 'tiqets_by_price': [('976786', 99.0)], 'tiqets_average_rating': 4.5, 'total_ratings': 233, 'place': 'No matching Place', 'description': ['duomo', 'history', 'lesson', 'peek', 'at', 'da', 'vincis', 'last', 'supper'], 'score': 0}
# {'venue': 'Designer Outlet Shuttle Bus from Milan', 'average_price': 20.0, 'tiqets_by_price': [('975775', 10.0), ('974878', 25.0), ('1103152', 25.0)], 'tiqets_average_rating': 2.9333333333333336, 'total_ratings': 184, 'place': 'No matching Place', 'description': ['3070', 'off', 'at', 'over', '170', 'stores', 'europes', 'biggest', 'mall', 'experience', 'unique', 'luxury', 'comfort', 'journey', 'serravalle', 'italian', 'designers', 'international', 'brands', 'at', 'up', '70', 'off'], 'score': 0}
# {'venue': 'Lake Como Day Trips from Milan', 'average_price': 95.658, 'tiqets_by_price': [('1034810', 85.0), ('981341', 85.0), ('977978', 89.0), ('1088294', 97.79), ('1092713', 121.5)], 'tiqets_average_rating': 4.62, 'total_ratings': 71, 'place': 'No matching Place', 'description': ['see', 'very', 'best', 'switzerland', 'italy', 'one', 'day', 'see', 'best', 'lake', 'como', 'picturesque', 'lugano', 'switzerland', 'one', 'day', 'explore', 'dual', 'countries', 'single', 'day', 'with', 'private', 'boat', 'cruise', 'break', 'from', 'hustle', 'bustle', 'milan', 'with', 'guided', 'trip', 'lake', 'como', 'discover', 'two', 'nations', 'single', 'day', 'adventure'], 'score': 0}
# {'venue': 'Milan City Cards', 'average_price': 57.284285714285716, 'tiqets_by_price': [('1063117', 13.99), ('1049131', 25.0), ('1082752', 39.0), ('1084869', 60.0), ('1013948', 74.0), ('1085043', 90.0), ('974740', 99.0)], 'tiqets_average_rating': 3.657142857142857, 'total_ratings': 299, 'place': 'No matching Place', 'description': ['see', 'more', 'save', 'more', 'milan', 'with', 'convenient', 'public', 'transport', 'card', 'see', 'best', 'milan', '48', '72', 'hours', 'including', 'la', 'scala', 'museum', 'more', 'see', 'best', 'milan', 'has', 'offer', 'leonardo3', 'museum', 'duomo', 'more', 'all', 'milans', 'mustsees', 'one', 'easy', 'package', 'save', 'up', '70', 'milan’s', 'top', 'attractions', 'with', 'handy', 'city', 'pass', 'enjoy', 'access', 'four', 'milans', 'stunning', 'house', 'museums', 'save', 'up', '70', 'milan’s', 'top', 'attractions', 'with', 'this', 'handy', 'city', 'pass'], 'score': 0}
# {'venue': 'Branca Tower', 'average_price': 22.0, 'tiqets_by_price': [('1098906', 6.0), ('1103227', 38.0)], 'tiqets_average_rating': 1.5, 'total_ratings': 13, 'place': 'No matching Place', 'description': ['ascend', 'top', 'be', 'amazed', 'by', 'scenic', 'views', 'milans', 'skyline'], 'score': 0}
# {'venue': 'Bernina Express Milan', 'average_price': 143.75, 'tiqets_by_price': [('1091029', 129.0), ('1101062', 148.0), ('975297', 149.0), ('1093195', 149.0)], 'tiqets_average_rating': 3.525, 'total_ratings': 43, 'place': 'No matching Place', 'description': ['ride', 'one', 'worlds', 'most', 'stunning', 'railroads', 'see', 'amazing', 'alpine', 'scenery', 'travel', 'bernina', 'express', 'enjoy', 'amazing', 'views', 'alps', 'discover', 'scenic', 'landscapes', 'alpine', 'escapades', 'tiranos', 'medieval', 'allure', 'enjoy', 'unforgettable', 'trip', 'two', 'most', 'famous', 'mountain', 'railways', 'lines'], 'score': 0}
# {'venue': 'Milan Cruises', 'average_price': 26.0, 'tiqets_by_price': [('1032326', 19.0), ('1056949', 33.0)], 'tiqets_average_rating': 3.4, 'total_ratings': 79, 'place': 'No matching Place', 'description': ['get', 'know', 'milan', 'take', 'boat', 'tour', 'canals', 'dock', 'sail', 'navigli', 'milanesi', 'sipping', 'favorite', 'cocktail'], 'score': 0}
# {'venue': 'Malpensa Airport Transfer', 'average_price': 10.0, 'tiqets_by_price': [('977181', 10.0)], 'tiqets_average_rating': 4.5, 'total_ratings': 171, 'place': 'No matching Place', 'description': ['grab', 'shuttle', 'bus', 'ticket', 'zoom', 'between', 'milan', 'malpensa', 'airport'], 'score': 0}
# {'venue': 'Milan Audio Guides', 'average_price': 6.0, 'tiqets_by_price': [('1013812', 6.0)], 'tiqets_average_rating': 3.8, 'total_ratings': 51, 'place': 'No matching Place', 'description': ['explore', '130', 'highlights', 'very', 'best', 'milan'], 'score': 0}
# {'venue': 'Milan Natural History Museum', 'average_price': 13.5, 'tiqets_by_price': [('1093489', 13.5), ('1093492', 13.5)], 'tiqets_average_rating': 2.0, 'total_ratings': 3, 'place': 'No matching Place', 'description': ['step', 'into', 'vibrant', 'world', 'modern', 'art', 'accompanied', 'by', 'audio', 'guide', 'explore', 'museums', 'collection', 'revealing', 'mysteries', 'evolutionary', 'stories'], 'score': 0}
# {'venue': 'Bagatti Valsecchi Museum', 'average_price': 12.0, 'tiqets_by_price': [('1026315', 12.0)], 'tiqets_average_rating': 4.7, 'total_ratings': 28, 'place': 'No matching Place', 'description': ['see', 'renaissance', 'come', 'life', 'this', 'stunning', 'house', 'museum'], 'score': 0}
# {'venue': 'QC Terme Milano', 'average_price': 74.0, 'tiqets_by_price': [('1019850', 74.0)], 'tiqets_average_rating': 4.4, 'total_ratings': 48, 'place': 'No matching Place', 'description': ['relax', 'day', 'away', 'therapeutic', 'waters', 'qc', 'terme', 'milano'], 'score': 0}
# {'venue': 'Next Exhibition Milan', 'average_price': 19.0, 'tiqets_by_price': [('1101831', 19.0)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['visit', 'exhibition', 'see', 'barbie', 'displays', 'interact', 'with', 'pink', 'world'], 'score': 0}
# {'venue': 'Milan Food Tours', 'average_price': 82.46000000000001, 'tiqets_by_price': [('1062022', 27.3), ('1049730', 85.0), ('1092554', 85.0), ('1092553', 96.0), ('1088280', 119.0)], 'tiqets_average_rating': 1.8800000000000001, 'total_ratings': 10, 'place': 'No matching Place', 'description': ['get', 'taste', 'classic', 'american', 'cuisine', 'at', 'hard', 'rock', 'cafe', 'milan', 'join', 'expert', 'chefs', 'handson', 'culinary', 'experience', 'milan', 'explore', 'navigli', 'taste', 'street', 'food', 'enjoy', 'delicious', 'milanese', 'aperitivo', 'get', 'ready', 'succumb', 'italys', 'hidden', 'culinary', 'gems', 'master', 'italian', 'cooking', 'professional', 'chefled', 'class'], 'score': 0}
# {'venue': 'Cripta del Santo Sepulcro', 'average_price': 9.5, 'tiqets_by_price': [('1062104', 9.5)], 'tiqets_average_rating': 3.8, 'total_ratings': 12, 'place': 'No matching Place', 'description': ['visit', 'crypt', 'san', 'sepolcro', 'immerse', 'yourself', 'sacred', 'history'], 'score': 0}
# {'venue': 'Milan Luggage Storage', 'average_price': 6.75, 'tiqets_by_price': [('1098928', 6.75)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['store', 'heavy', 'baggage', 'at', 'secure', 'luggage', 'storage', 'facility'], 'score': 0}
# {'venue': 'Lake Como Tours', 'average_price': 117.0, 'tiqets_by_price': [('1093738', 117.0)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['discover', 'swiss', 'italian', 'cultures', 'daylong', 'adventure'], 'score': 0}
# {'venue': 'STEP FuturAbility District', 'average_price': 14.0, 'tiqets_by_price': [('1058832', 14.0)], 'tiqets_average_rating': 3.0, 'total_ratings': 2, 'place': 'No matching Place', 'description': ['take', 'journey', 'into', 'future', 'with', 'step'], 'score': 0}
# {'venue': 'Cinque Terre Day Trips from Milan', 'average_price': 130.5, 'tiqets_by_price': [('1092722', 130.5)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['beautiful', 'journey', 'from', 'milan', 'colorful', 'coastal', 'villages', 'cinque', 'terre'], 'score': 0}
# {'venue': 'Iseo lake Day Trips from Milan', 'average_price': 108.0, 'tiqets_by_price': [('1058596', 108.0)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['explore', 'mountains', 'outside', 'milan', 'day', 'trip', 'lake', 'iseo'], 'score': 0}
# {'venue': 'Switzerland Day Trips from Milan', 'average_price': 139.0, 'tiqets_by_price': [('1093192', 139.0)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['enjoy', 'views', 'swiss', 'alps', 'explore', 'interlakens', 'charm'], 'score': 0}
# {'venue': 'Palermo Cooking Classes', 'average_price': 69.0, 'tiqets_by_price': [('1089298', 69.0)], 'tiqets_average_rating': 5.0, 'total_ratings': 2, 'place': 'No matching Place', 'description': ['master', 'art', 'crafting', 'italys', 'two', 'lovable', 'dishes', 'under', 'expert'], 'score': 0}
# {'venue': 'Lake Maggiore Day Trips from Milan', 'average_price': 103.0, 'tiqets_by_price': [('1092718', 103.0)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['witness', 'beauty', 'lake', 'maggiore', 'cruise', 'scenic', 'borromean', 'islands'], 'score': 0}
# {'venue': 'Milano Centrale Transfer', 'average_price': 11.5, 'tiqets_by_price': [('1101705', 11.5)], 'tiqets_average_rating': 0.0, 'total_ratings': 0, 'place': 'No matching Place', 'description': ['explore', 'lake', 'garda', 'impressive', 'landscape', 'via', 'direct', 'train'], 'score': 0}

# %%
def calculate_place_common_categories(place_categories, user_preferred_categories):
    if (len(user_preferred_categories)>0):
        user_preferred_categories_set = set(user_preferred_categories)

        common = user_preferred_categories_set.intersection(place_categories)
        return len(common) / len(user_preferred_categories)
    return 0

# %%
from datetime import datetime, time, timedelta

def is_open(date, hours):
    # Check if hours is valid
    if not hours:
        return False

    # Adjust to match 0=Sunday, ..., 6=Saturday
    day_of_week = (date.weekday() + 1) % 7

    for period in hours:
        if period['open']['day'] == day_of_week:
            # Extract opening and closing times for this day
            open_time = time(hour=period['open']['hour'], minute=period['open']['minute'])
            close_time = time(hour=period['close']['hour'], minute=period['close']['minute'])

            # Check if the current time falls within the open and close times
            if open_time < date.time() or date.time() < close_time:
                return True
    return False


def amount_of_open_days(opening_hours, arrival_date, departure_date):
    if not opening_hours:
        return 0  # If no opening hours are provided, assume closed

    count = 0
    current_date = arrival_date
    while current_date <= departure_date:
        if (
            (current_date == arrival_date and is_open(current_date, opening_hours)) or
            (current_date == departure_date and is_open(current_date, opening_hours))
        ):
            count += 1
        else:
            if any(is_open(datetime.combine(current_date.date(), time(hour=h['open']['hour'], minute=h['open']['minute'])), opening_hours) for h in opening_hours):
                count += 1

        current_date += timedelta(days=1)

    return count

# %%
import math

def count_days_between(arrival_date, departure_date):

    if isinstance(arrival_date, str):
        arrival_date = datetime.strptime(arrival_date, "%Y-%m-%d %H:%M:%S")
    if isinstance(departure_date, str):
        departure_date = datetime.strptime(departure_date, "%Y-%m-%d %H:%M:%S")

    delta = departure_date - arrival_date

    return math.ceil(delta.total_seconds() / (60 * 60 * 24))

# %%
def remove_unavailable_places(merged_data, user_dates):
    
    start_date = datetime.strptime(user_dates.get('start_date'), '%Y-%m-%dT%H:%M:%S')
    end_date = datetime.strptime(user_dates.get('end_date'), '%Y-%m-%dT%H:%M:%S')

    for tiqetXplace in merged_data.get("tiqetsXplaces"):
        opening_hours = tiqetXplace.get('opening_hours')
        if amount_of_open_days(opening_hours, start_date, end_date) == 0:
            merged_data.get("tiqetsXplaces").remove(tiqetXplace)

    for place in merged_data.get("places_only"):
        opening_hours = place.get('opening_hours')
        if amount_of_open_days(opening_hours, start_date, end_date) == 0:
            merged_data.get("places_only").remove(place)

    return merged_data

# %%
def get_max_total_ratings(tiqets):
    max = 0
    for tiqet in tiqets:
        total = tiqet.get('total_ratings')
        if (total > max):
            max = total
            print

    return max

# %%
def calculate_weighted_rating(rating, num_reviews, global_average_rating, min_reviews=10):

    if num_reviews == 0:
        return 0

    weighted_rating = (rating * num_reviews + global_average_rating * min_reviews) / (num_reviews + min_reviews)
    return weighted_rating

# %%
def recommend(user_preferences):
        lat = user_preferences.get('lat')
        lng = user_preferences.get('lng')
        radius = user_preferences.get('radius')
        dates = user_preferences.get('dates')
        participants = user_preferences.get('participants')
        categories = user_preferences.get('categories')
        budget = user_preferences.get('budget')

        merged_data = merge_tiqets_and_places(lat, lng, radius)

        # Remove places that are never open during the user's visit
        merged_data = remove_unavailable_places(merged_data, dates)

        recommendations = []

        for tiqetXplace in merged_data.get("tiqetsXplaces"):
                recommendation_score = 0

                rating = tiqetXplace.get('rating', 0) # rating value between 0 and 5
                normalized_rating = rating / 5 # rating value between 0 and 1

                category_score = calculate_place_common_categories(tiqetXplace.get('categories', []), categories) # category accuracy value between 0 and 1

                recommendation_score = (normalized_rating * 0.35) + (category_score * 0.65)

                recommendations.append({
                        'type': 'tiqetsXplaces',
                        'place': tiqetXplace.get('place'),
                        'venue': tiqetXplace.get('venue'),
                        'average_price': tiqetXplace.get('average_price'),
                        'recommended_score': recommendation_score
                })

        for place in merged_data.get("places_only"):
                recommendation_score = 0

                rating = place.get('rating', 0)  # rating value between 0 and 5
                normalized_rating = rating / 5 # rating value between 0 and 1

                category_score = calculate_place_common_categories(place.get('categories', []), categories) # category accuracy value between 0 and 1

                recommendation_score = (normalized_rating * 0.35) + (category_score * 0.65)

                recommendations.append({
                        'type': 'places_only',
                        'place': place.get('place'),
                        'venue': place.get('venue'),
                        'average_price': place.get('average_price'),
                        'recommended_score': recommendation_score
                })

        global_average_rating = sum(item['tiqets_average_rating'] 
                                    for item in merged_data.get("tiqets_only") 
                                    if item['tiqets_average_rating']) / len(merged_data.get("tiqets_only"))
        
        for tiqet in merged_data.get("tiqets_only"):

                recommendation_score = 0

                rating = tiqet.get('tiqets_average_rating', 0) # rating value between 0 and 10
                total_ratings = tiqet.get('total_ratings')

                weighted_rating = calculate_weighted_rating(rating, total_ratings,global_average_rating)

                normalized_rating = weighted_rating / 5 # rating value between 0 and 1
                
                category_score = calculate_place_common_categories(tiqet.get('categories', []), categories)

                recommendation_score = (normalized_rating * 0.35) + (category_score * 0.65)

                recommendations.append({
                        'type': 'tiqets_only',
                        'place': tiqet.get('place'),
                        'venue': tiqet.get('venue'),
                        'average_price': tiqet.get('average_price'),
                        'recommended_score': recommendation_score
                })

        if budget == 'Cheap':
                recommendations = sorted(
                        (rec for rec in recommendations if rec.get('average_price') is not None),
                        key=lambda rec: rec['average_price']
                )


        top_recommendations = sorted(
                recommendations,
                key=lambda rec: rec['recommended_score'],
                reverse=True)[:10]


        return top_recommendations

# %% [markdown]
# ### Test

# %%
user_preferences = {
    'lat':lat,
    'lng':lng,
    'radius':radius,
    'categories': [],
    'budget':"Expensive",
    'dates':{
        'start_date': '2024-11-22T08:00:00', 
        'end_date': '2024-11-24T18:30:00'
      }
    }

recommend(user_preferences)
# Out:
# [{'type': 'tiqetsXplaces',
#   'place': 'Duomo di Milano',
#   'venue': 'Milan Cathedral – The Duomo',
#   'average_price': 56.1,
#   'recommended_score': 0.33599999999999997},
#  {'type': 'tiqetsXplaces',
#   'place': 'Sforzesco Castle',
#   'venue': 'Castello Sforzesco',
#   'average_price': 31.7,
#   'recommended_score': 0.329},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca di Brera',
#   'venue': 'Pinacoteca di Brera',
#   'average_price': 59.9,
#   'recommended_score': 0.329},
#  {'type': 'tiqetsXplaces',
#   'place': 'Villa Necchi Campiglio',
#   'venue': 'Villa Necchi Campiglio',
#   'average_price': 18.5,
#   'recommended_score': 0.329},
#  {'type': 'places_only',
#   'place': "Basilica of Sant'Ambrogio",
#   'venue': 'No matching Venue',
#   'average_price': None,
#   'recommended_score': 0.329},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Casa Milan Museum',
#   'average_price': 16.5,
#   'recommended_score': 0.3265643640288587},
#  {'type': 'tiqetsXplaces',
#   'place': 'Leonardo da Vinci Museum of Science and Technology',
#   'venue': 'National Museum Science and Technology Leonardo da Vinci',
#   'average_price': 10.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': "Leonardo's Last Supper Museum",
#   'venue': 'The Last Supper',
#   'average_price': 80.5,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca Ambrosiana',
#   'venue': 'Biblioteca Ambrosiana',
#   'average_price': 20.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'places_only',
#   'place': 'Basilica di Santa Maria delle Grazie',
#   'venue': 'No matching Venue',
#   'average_price': None,
#   'recommended_score': 0.32199999999999995}]

# %% [markdown]
# ### Test using Cheap Budget

# %%
user_preferences = {
    'lat':lat,
    'lng':lng,
    'radius':radius,
    'categories': [],
    'budget':"Cheap",
    'dates':{
        'start_date': '2024-11-22T08:00:00', 
        'end_date': '2024-11-24T18:30:00'
      }
}

recommend(user_preferences)
# Out:
# [{'type': 'tiqetsXplaces',
#   'place': 'Duomo di Milano',
#   'venue': 'Milan Cathedral – The Duomo',
#   'average_price': 47.88333333333333,
#   'recommended_score': 0.33599999999999997},
#  {'type': 'tiqetsXplaces',
#   'place': 'Villa Necchi Campiglio',
#   'venue': 'Villa Necchi Campiglio',
#   'average_price': 18.5,
#   'recommended_score': 0.329},
#  {'type': 'tiqetsXplaces',
#   'place': 'Sforzesco Castle',
#   'venue': 'Castello Sforzesco',
#   'average_price': 31.7,
#   'recommended_score': 0.329},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca di Brera',
#   'venue': 'Pinacoteca di Brera',
#   'average_price': 59.9,
#   'recommended_score': 0.329},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Casa Milan Museum',
#   'average_price': 16.5,
#   'recommended_score': 0.3263709878997898},
#  {'type': 'tiqetsXplaces',
#   'place': 'Leonardo da Vinci Museum of Science and Technology',
#   'venue': 'National Museum Science and Technology Leonardo da Vinci',
#   'average_price': 10.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca Ambrosiana',
#   'venue': 'Biblioteca Ambrosiana',
#   'average_price': 20.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': "Leonardo's Last Supper Museum",
#   'venue': 'The Last Supper',
#   'average_price': 80.5,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Leonardo3 Museum',
#   'average_price': 19.0,
#   'recommended_score': 0.3107432446057673},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Santa Maria delle Grazie',
#   'average_price': 99.0,
#   'recommended_score': 0.30900901092663546}]

# %% [markdown]
# ### Test using categories

# %%
user_preferences = {
    'lat':lat,
    'lng':lng,
    'radius':radius,
    'categories': ["Museum","art_gallery","architecture","history","church","boat"],
    'budget':"Cheap",
    'dates':{
        'start_date': '2024-11-22T08:00:00', 
        'end_date': '2024-11-24T18:30:00'
      }
}

recommend(user_preferences)
# Out:
# [{'type': 'tiqetsXplaces',
#   'place': 'Duomo di Milano',
#   'venue': 'Milan Cathedral – The Duomo',
#   'average_price': 56.1,
#   'recommended_score': 0.4443333333333333},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca di Brera',
#   'venue': 'Pinacoteca di Brera',
#   'average_price': 59.9,
#   'recommended_score': 0.43733333333333335},
#  {'type': 'tiqetsXplaces',
#   'place': 'Villa Necchi Campiglio',
#   'venue': 'Villa Necchi Campiglio',
#   'average_price': 18.5,
#   'recommended_score': 0.329},
#  {'type': 'tiqetsXplaces',
#   'place': 'Sforzesco Castle',
#   'venue': 'Castello Sforzesco',
#   'average_price': 31.7,
#   'recommended_score': 0.329},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Casa Milan Museum',
#   'average_price': 16.5,
#   'recommended_score': 0.3265643640288587},
#  {'type': 'tiqetsXplaces',
#   'place': 'Leonardo da Vinci Museum of Science and Technology',
#   'venue': 'National Museum Science and Technology Leonardo da Vinci',
#   'average_price': 10.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': 'Pinacoteca Ambrosiana',
#   'venue': 'Biblioteca Ambrosiana',
#   'average_price': 20.0,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqetsXplaces',
#   'place': "Leonardo's Last Supper Museum",
#   'venue': 'The Last Supper',
#   'average_price': 80.5,
#   'recommended_score': 0.32199999999999995},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Leonardo3 Museum',
#   'average_price': 19.0,
#   'recommended_score': 0.3110864589635007},
#  {'type': 'tiqets_only',
#   'place': 'No matching Place',
#   'venue': 'Santa Maria delle Grazie',
#   'average_price': 99.0,
#   'recommended_score': 0.309492053356038}]
